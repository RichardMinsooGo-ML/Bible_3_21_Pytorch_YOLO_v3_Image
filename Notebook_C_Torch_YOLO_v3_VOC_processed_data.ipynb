# %% [markdown]
# # 1. [Opt] Check GPU Type

# %%
# Check GPU Type
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
    print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
    print('and then re-execute this cell.')
else:
    print(gpu_info)
# Out:
# Wed Dec  7 23:21:16 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   69C    P0    31W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # 2. Git Clone from Github Repository to root directory
# At Colab, location is "/content/".
#
# Using `$ git clone https://github.com/lainyzine/git-clone.git` will load the Github repository with the name of the repository. With Colab, it can be convenient to work in the root directory. You can use the command to call the root directory as shown below.
#
# According to the Github repository, we can use `! git pull origin main` or `! Just use git pull origin master`.

# %%
# Clone from Github Repository
! git init .
! git remote add origin https://github.com/RichardMinsooGo-ML/Bible_3_21_Pytorch_YOLO_v3_Image.git
# ! git pull origin master
! git pull origin main
# Out:
# Initialized empty Git repository in /content/.git/
# remote: Enumerating objects: 1948, done.
# remote: Counting objects: 100% (89/89), done.
# remote: Compressing objects: 100% (86/86), done.
# remote: Total 1948 (delta 49), reused 2 (delta 2), pack-reused 1859
# Receiving objects: 100% (1948/1948), 58.68 MiB | 53.22 MiB/s, done.
# Resolving deltas: 100% (806/806), done.
# From https://github.com/RichardMinsooGo-ML/Bible_3_16_Pytorch_YOLO_v3_Image
#  * branch            main       -> FETCH_HEAD
#  * [new branch]      main       -> origin/main

# %% [markdown]
# # 3. import clear_output

# %%
from IPython.display import clear_output 
clear_output()

# %% [markdown]
# # 4. VOC dataset download from Auther's Github repository

# %%
# !pip install --upgrade --no-cache-dir gdown

# VOC dataset download from Auther's Github repository
import gdown
google_path = 'https://drive.google.com/uc?id='
file_id = '1pq2LOUkRCbwp-rSD1lm5PI747pg5dDk_'
output_name = 'VOC_2012.zip'
gdown.download(google_path+file_id,output_name,quiet=False)
# https://drive.google.com/file/d/1pq2LOUkRCbwp-rSD1lm5PI747pg5dDk_/view?usp=sharing

# !unzip /content/VOC_2012.zip -d /content/dataset/VOC2012
clear_output()
! rm /content/VOC_2012.zip

# %% [markdown]
# # 5. [Opt] Check Memory Space

# %%
# Memory Space
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
    print('To enable a high-RAM runtime, select the Runtime > "Change runtime type"')
    print('menu, and then select High-RAM in the Runtime shape dropdown. Then, ')
    print('re-execute this cell.')
else:
    print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 27.3 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %% [markdown]
# # 6. install terminaltables for Ascii Table print

# %%
# !pip install terminaltables
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting terminaltables
#   Downloading terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Installing collected packages: terminaltables
# Successfully installed terminaltables-3.1.10

# %% [markdown]
# # 7. Download Darknet Weights

# %%
# Download Darknet Weights
# ! wget https://pjreddie.com/media/files/yolo-voc.weights 
! wget https://pjreddie.com/media/files/yolov3-tiny.weights 
! wget https://pjreddie.com/media/files/yolov3.weights
# ! wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v3_optimal/yolov4.weights 
# ! wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v4_pre/yolov4-tiny.weights

import shutil
shutil.move("/content/yolov3-tiny.weights", "/content/checkpoints")
shutil.move("/content/yolov3.weights", "/content/checkpoints")
# shutil.move("/content/yolov4-tiny.weights", "/content/tmp")
# shutil.move("/content/yolov4.weights", "/content/tmp") 
shutil.rmtree("sample_data")
# Out:
# --2022-12-07 23:22:05--  https://pjreddie.com/media/files/yolov3-tiny.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35434956 (34M) [application/octet-stream]
# Saving to: ‘yolov3-tiny.weights’
#
# yolov3-tiny.weights 100%[===================>]  33.79M  27.4MB/s    in 1.2s
#
# 2022-12-07 23:22:06 (27.4 MB/s) - ‘yolov3-tiny.weights’ saved [35434956/35434956]
#
# --2022-12-07 23:22:06--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  39.5MB/s    in 6.3s
#
# 2022-12-07 23:22:13 (37.3 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %% [markdown]
# # 8. YOLO v3 Pre-Trained Weight gdown from Auther's GDrive

# %%
google_path = 'https://drive.google.com/uc?id='
file_id = '1ZOqdFdqSnHUd9X_TfBGktScjDTeeZ8gc'
output_name = 'Yolo_V3_VOC.pth'
gdown.download(google_path+file_id,output_name,quiet=False)
# https://drive.google.com/file/d/1ZOqdFdqSnHUd9X_TfBGktScjDTeeZ8gc/view?usp=sharing

shutil.move("/content/Yolo_V3_VOC.pth", "./checkpoints")
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ZOqdFdqSnHUd9X_TfBGktScjDTeeZ8gc
# To: /content/Yolo_V3_VOC.pth
# 100%|██████████| 248M/248M [00:03<00:00, 73.4MB/s]
# './checkpoints/Yolo_V3_VOC.pth'

# %% [markdown]
# # 9. YOLO v3-tiny Pre-Trained Weight gdown from Auther's GDrive

# %%
google_path = 'https://drive.google.com/uc?id='
file_id = '1hbz__T-j1Si2o6fGkjhYxRZRsvCTOnCH'
output_name = 'Yolo_V3_VOC_tiny.pth'
gdown.download(google_path+file_id,output_name,quiet=False)
# https://drive.google.com/file/d/1hbz__T-j1Si2o6fGkjhYxRZRsvCTOnCH/view?usp=sharing

shutil.move("/content/Yolo_V3_VOC_tiny.pth", "./checkpoints")
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1hbz__T-j1Si2o6fGkjhYxRZRsvCTOnCH
# To: /content/Yolo_V3_VOC_tiny.pth
# 100%|██████████| 35.5M/35.5M [00:00<00:00, 94.2MB/s]
# './checkpoints/Yolo_V3_VOC_tiny.pth'

# %%
# from google.colab import drive 
# drive.mount('/content/gdrive/')

# %% [markdown]
# # 10. Train YOLO v3 from Pre-trained Weights

# %%
! python train.py --num_epochs 3 --batch_size 8 --data_config config/VOC.data --model_def config/yolov3.cfg --pretrained_path checkpoints/Yolo_V3_VOC.pth --save_path checkpoints/Yolo_V3_VOC.pth
# Out:
# {'data_config': 'config/VOC.data', 'model_def': 'config/yolov3.cfg', 'pretrained_path': 'checkpoints/Yolo_V3_VOC.pth', 'save_path': 'checkpoints/Yolo_V3_VOC.pth', 'working_dir': './', 'num_epochs': 3, 'batch_size': 8, 'img_size': 416, 'n_cpu': 1, 'gradient_accumulations': 2, 'evaluation_interval': 2, 'multiscale_training': True, 'checkpoint_freq': 2, 'iou_thres': 0.5, 'conf_thres': 0.5, 'nms_thres': 0.5, 'ckpt_dir': './checkpoints', 'logs_dir': './logs'}
# cuda
# checkpoints/Yolo_V3_VOC.pth
# Trained pytorch weight loaded!
# 1713
#  33% 570/1713 [04:32<08:38,  2.20it/s]
# ---- [Epoch 1/3, Batch 571/1713] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 10           | 20           | 40           |
# | loss       | 1.920281     | 1.422953     | 1.260975     |
# | loss_x     | 0.009751     | 0.026074     | 0.026939     |
# | loss_y     | 0.039714     | 0.039329     | 0.090881     |
# | loss_w     | 0.024627     | 0.015980     | 0.026018     |
# | loss_h     | 0.015866     | 0.032222     | 0.012984     |
# | loss_obj   | 1.814114     | 1.292065     | 1.087583     |
# | loss_cls   | 0.016209     | 0.017283     | 0.016569     |
# | cls_acc    | 80.00%       | 73.33%       | 73.33%       |
# | conf_obj   | 0.457333     | 0.598716     | 0.660435     |
# | conf_noobj | 0.006381     | 0.005282     | 0.004663     |
# +------------+--------------+--------------+--------------+
# Total loss 4.604208469390869
# ---- ETA 0:09:06.020786
#  67% 1141/1713 [09:02<03:52,  2.46it/s]
# ---- [Epoch 1/3, Batch 1142/1713] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 10           | 20           | 40           |
# | loss       | 2.060895     | 1.846706     | 2.133714     |
# | loss_x     | 0.042360     | 0.078037     | 0.080215     |
# | loss_y     | 0.044103     | 0.044034     | 0.052635     |
# | loss_w     | 0.014661     | 0.012997     | 0.011116     |
# | loss_h     | 0.084324     | 0.061165     | 0.030325     |
# | loss_obj   | 1.854231     | 1.630669     | 1.930247     |
# | loss_cls   | 0.021215     | 0.019805     | 0.029176     |
# | cls_acc    | 70.00%       | 70.00%       | 70.00%       |
# | conf_obj   | 0.460922     | 0.532529     | 0.668361     |
# | conf_noobj | 0.004300     | 0.003949     | 0.003417     |
# +------------+--------------+--------------+--------------+
# Total loss 6.041315078735352
# ---- ETA 0:04:31.606180
# 100% 1712/1713 [13:22<00:00,  2.70it/s]
# ---- [Epoch 1/3, Batch 1713/1713] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 12           | 24           | 48           |
# | loss       | 2.174837     | 1.332109     | 1.284428     |
# | loss_x     | 0.008830     | 0.011366     | 0.059425     |
# | loss_y     | 0.014321     | 0.027396     | 0.052522     |
# | loss_w     | 0.071886     | 0.129135     | 0.019107     |
# | loss_h     | 0.067457     | 0.046134     | 0.018923     |
# | loss_obj   | 1.980558     | 1.084476     | 1.101765     |
# | loss_cls   | 0.031786     | 0.033602     | 0.032686     |
# | cls_acc    | 42.86%       | 28.57%       | 28.57%       |
# | conf_obj   | 0.385233     | 0.554357     | 0.582183     |
# | conf_noobj | 0.004032     | 0.003083     | 0.002964     |
# +------------+--------------+--------------+--------------+
# Total loss 4.7913737297058105
# ---- ETA 0:00:00
# 100% 1713/1713 [13:22<00:00,  2.13it/s]
# Current epoch loss : 6.26048 Saved at checkpoints/Yolo_V3_VOC.pth
# 1713
#  33% 570/1713 [04:29<10:52,  1.75it/s]
# ---- [Epoch 2/3, Batch 571/1713] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 16           | 32           | 64           |
# | loss       | 2.414488     | 2.058458     | 1.759823     |
# | loss_x     | 0.061397     | 0.064254     | 0.059885     |
# | loss_y     | 0.031463     | 0.075597     | 0.093607     |
# | loss_w     | 0.076472     | 0.037806     | 0.044415     |
# | loss_h     | 0.034233     | 0.007418     | 0.014032     |
# | loss_obj   | 2.188497     | 1.854744     | 1.527558     |
# | loss_cls   | 0.022426     | 0.018640     | 0.020326     |
# | cls_acc    | 68.42%       | 78.95%       | 73.68%       |
# | conf_obj   | 0.424262     | 0.488418     | 0.552384     |
# | conf_noobj | 0.007377     | 0.005540     | 0.005073     |
# +------------+--------------+--------------+--------------+
# Total loss 6.232769012451172
# ---- ETA 0:35:47.854124
#  67% 1141/1713 [09:06<04:48,  1.98it/s]
# ---- [Epoch 2/3, Batch 1142/1713] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 10           | 20           | 40           |
# | loss       | 1.944962     | 2.008294     | 1.706595     |
# | loss_x     | 0.028021     | 0.020481     | 0.081478     |
# | loss_y     | 0.025481     | 0.035046     | 0.051673     |
# | loss_w     | 0.087681     | 0.029088     | 0.060284     |
# | loss_h     | 0.037691     | 0.017209     | 0.012225     |
# | loss_obj   | 1.733579     | 1.867138     | 1.465288     |
# | loss_cls   | 0.032510     | 0.039332     | 0.035646     |
# | cls_acc    | 46.67%       | 43.75%       | 31.25%       |
# | conf_obj   | 0.529722     | 0.488469     | 0.581869     |
# | conf_noobj | 0.005293     | 0.005374     | 0.004187     |
# +------------+--------------+--------------+--------------+
# Total loss 5.65985107421875
# ---- ETA 0:11:15.210753
# 100% 1712/1713 [13:45<00:00,  1.48it/s]
# ---- [Epoch 2/3, Batch 1713/1713] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 15           | 30           | 60           |
# | loss       | 2.144706     | 2.029316     | 2.004877     |
# | loss_x     | 0.046668     | 0.054516     | 0.061907     |
# | loss_y     | 0.057386     | 0.050449     | 0.047918     |
# | loss_w     | 0.079223     | 0.043873     | 0.564975     |
# | loss_h     | 0.022759     | 0.020825     | 0.288294     |
# | loss_obj   | 1.892805     | 1.812937     | 0.993178     |
# | loss_cls   | 0.045864     | 0.046716     | 0.048605     |
# | cls_acc    | 30.00%       | 20.00%       | 20.00%       |
# | conf_obj   | 0.515103     | 0.542865     | 0.747709     |
# | conf_noobj | 0.007642     | 0.006697     | 0.005271     |
# +------------+--------------+--------------+--------------+
# Total loss 6.178899765014648
# ---- ETA 0:00:00
# 100% 1713/1713 [13:45<00:00,  2.07it/s]
# Current epoch loss : 6.26306 Saved at checkpoints/Yolo_V3_VOC.pth
# 1713
#  33% 570/1713 [04:16<08:31,  2.24it/s]
# ---- [Epoch 3/3, Batch 571/1713] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 13           | 26           | 52           |
# | loss       | 2.464831     | 1.878011     | 1.607760     |
# | loss_x     | 0.063554     | 0.078125     | 0.060359     |
# | loss_y     | 0.038789     | 0.049504     | 0.115830     |
# | loss_w     | 0.103081     | 0.030450     | 0.034863     |
# | loss_h     | 0.099675     | 0.039219     | 0.024287     |
# | loss_obj   | 2.128953     | 1.648520     | 1.344379     |
# | loss_cls   | 0.030778     | 0.032192     | 0.028042     |
# | cls_acc    | 46.67%       | 33.33%       | 46.67%       |
# | conf_obj   | 0.345218     | 0.452164     | 0.541789     |
# | conf_noobj | 0.004891     | 0.004341     | 0.003854     |
# +------------+--------------+--------------+--------------+
# Total loss 5.950601577758789
# ---- ETA 1:02:54.550019
#  67% 1141/1713 [08:42<05:33,  1.72it/s]
# ---- [Epoch 3/3, Batch 1142/1713] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 16           | 32           | 64           |
# | loss       | 2.864128     | 2.555518     | 2.401262     |
# | loss_x     | 0.037735     | 0.079369     | 0.091934     |
# | loss_y     | 0.062099     | 0.088010     | 0.050672     |
# | loss_w     | 0.172431     | 0.051772     | 0.066155     |
# | loss_h     | 0.048029     | 0.037525     | 0.051026     |
# | loss_obj   | 2.518251     | 2.271519     | 2.116009     |
# | loss_cls   | 0.025583     | 0.027322     | 0.025466     |
# | cls_acc    | 52.94%       | 52.63%       | 57.89%       |
# | conf_obj   | 0.355485     | 0.342153     | 0.320638     |
# | conf_noobj | 0.005137     | 0.004611     | 0.004213     |
# +------------+--------------+--------------+--------------+
# Total loss 7.820908546447754
# ---- ETA 0:17:56.643916
# 100% 1712/1713 [13:25<00:00,  1.83it/s]
# ---- [Epoch 3/3, Batch 1713/1713] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 15           | 30           | 60           |
# | loss       | 2.329168     | 1.960531     | 1.714501     |
# | loss_x     | 0.043804     | 0.029783     | 0.083514     |
# | loss_y     | 0.047275     | 0.055572     | 0.104099     |
# | loss_w     | 0.007663     | 0.032975     | 0.020778     |
# | loss_h     | 0.016152     | 0.011819     | 0.015880     |
# | loss_obj   | 2.187678     | 1.815486     | 1.475307     |
# | loss_cls   | 0.026595     | 0.014896     | 0.014923     |
# | cls_acc    | 50.00%       | 66.67%       | 66.67%       |
# | conf_obj   | 0.441741     | 0.471874     | 0.558387     |
# | conf_noobj | 0.004906     | 0.004878     | 0.004098     |
# +------------+--------------+--------------+--------------+
# Total loss 6.004200458526611
# ---- ETA 0:00:00
# 100% 1713/1713 [13:26<00:00,  2.12it/s]
# Current epoch loss : 6.10715 Saved at checkpoints/Yolo_V3_VOC.pth
#
# ---- Evaluating Model ----
# Detecting objects: 100% 429/429 [01:21<00:00,  5.23it/s]
# Computing AP: 100% 20/20 [00:00<00:00, 317.55it/s]
# +-------+-------------+---------+
# | Index | Class name  | AP      |
# +-------+-------------+---------+
# | 0     | aeroplane   | 0.31889 |
# | 1     | bicycle     | 0.22595 |
# | 2     | bird        | 0.06771 |
# | 3     | boat        | 0.11169 |
# | 4     | bottle      | 0.23031 |
# | 5     | bus         | 0.20078 |
# | 6     | car         | 0.32961 |
# | 7     | cat         | 0.23743 |
# | 8     | chair       | 0.28815 |
# | 9     | cow         | 0.00018 |
# | 10    | diningtable | 0.16754 |
# | 11    | dog         | 0.16434 |
# | 12    | horse       | 0.05069 |
# | 13    | motorbike   | 0.13075 |
# | 14    | person      | 0.77410 |
# | 15    | pottedplant | 0.11426 |
# | 16    | sheep       | 0.12620 |
# | 17    | sofa        | 0.05975 |
# | 18    | train       | 0.10864 |
# | 19    | tvmonitor   | 0.31988 |
# +-------+-------------+---------+
# ---- mAP 0.20134171348436683

# %% [markdown]
# # 11. Train YOLO v3 from Darknet Weights

# %%
! python train.py --num_epochs 3 --batch_size 8 --data_config config/VOC.data --model_def config/yolov3.cfg --pretrained_path checkpoints/yolov3.weights --save_path checkpoints/Yolo_V3_VOC.pth
# Out:
# {'data_config': 'config/VOC.data', 'model_def': 'config/yolov3.cfg', 'pretrained_path': 'checkpoints/yolov3.weights', 'save_path': 'checkpoints/Yolo_V3_VOC.pth', 'working_dir': './', 'num_epochs': 3, 'batch_size': 8, 'img_size': 416, 'n_cpu': 1, 'gradient_accumulations': 2, 'evaluation_interval': 2, 'multiscale_training': True, 'checkpoint_freq': 2, 'iou_thres': 0.5, 'conf_thres': 0.5, 'nms_thres': 0.5, 'ckpt_dir': './checkpoints', 'logs_dir': './logs'}
# cuda
# checkpoints/yolov3.weights
# Darknet weight loaded!
# 1713
#  33% 570/1713 [04:40<08:40,  2.20it/s]
# ---- [Epoch 1/3, Batch 571/1713] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 13           | 26           | 52           |
# | loss       | 4.280295     | 4.255893     | 3.757606     |
# | loss_x     | 0.058689     | 0.059921     | 0.051128     |
# | loss_y     | 0.053708     | 0.046724     | 0.062508     |
# | loss_w     | 0.360166     | 0.161015     | 0.355506     |
# | loss_h     | 0.338250     | 0.105148     | 0.504666     |
# | loss_obj   | 3.419220     | 3.828448     | 2.730742     |
# | loss_cls   | 0.050261     | 0.054637     | 0.053056     |
# | cls_acc    | 9.52%        | 9.52%        | 9.52%        |
# | conf_obj   | 0.207192     | 0.295202     | 0.340816     |
# | conf_noobj | 0.007304     | 0.006635     | 0.006334     |
# +------------+--------------+--------------+--------------+
# Total loss 12.293793678283691
# ---- ETA 0:09:23.441322
#  67% 1141/1713 [09:29<06:20,  1.51it/s]
# ---- [Epoch 1/3, Batch 1142/1713] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 16           | 32           | 64           |
# | loss       | 3.548444     | 3.340427     | 3.390122     |
# | loss_x     | 0.058968     | 0.064323     | 0.066139     |
# | loss_y     | 0.094280     | 0.073569     | 0.126998     |
# | loss_w     | 0.071689     | 0.083619     | 0.149439     |
# | loss_h     | 0.055760     | 0.113815     | 0.197567     |
# | loss_obj   | 3.219028     | 2.960982     | 2.803423     |
# | loss_cls   | 0.048719     | 0.044119     | 0.046555     |
# | cls_acc    | 23.08%       | 23.08%       | 23.08%       |
# | conf_obj   | 0.163382     | 0.180586     | 0.206993     |
# | conf_noobj | 0.007352     | 0.006241     | 0.006611     |
# +------------+--------------+--------------+--------------+
# Total loss 10.278993606567383
# ---- ETA 0:04:44.879861
# 100% 1712/1713 [14:07<00:00,  2.25it/s]
# ---- [Epoch 1/3, Batch 1713/1713] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 10           | 20           | 40           |
# | loss       | 3.261349     | 2.847837     | 2.578858     |
# | loss_x     | 0.107596     | 0.085325     | 0.112538     |
# | loss_y     | 0.073560     | 0.052547     | 0.088742     |
# | loss_w     | 0.140101     | 0.153846     | 0.110425     |
# | loss_h     | 0.385897     | 0.063456     | 0.115754     |
# | loss_obj   | 2.516530     | 2.450413     | 2.101023     |
# | loss_cls   | 0.037665     | 0.042250     | 0.050375     |
# | cls_acc    | 37.50%       | 50.00%       | 37.50%       |
# | conf_obj   | 0.378518     | 0.359825     | 0.420331     |
# | conf_noobj | 0.008578     | 0.007947     | 0.007248     |
# +------------+--------------+--------------+--------------+
# Total loss 8.688043594360352
# ---- ETA 0:00:00
# 100% 1713/1713 [14:08<00:00,  2.02it/s]
# Current epoch loss : 9.67819 Saved at checkpoints/Yolo_V3_VOC.pth
# 1713
#  33% 570/1713 [04:38<08:15,  2.31it/s]
# ---- [Epoch 2/3, Batch 571/1713] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 13           | 26           | 52           |
# | loss       | 2.590401     | 2.594380     | 2.223173     |
# | loss_x     | 0.076806     | 0.066843     | 0.080242     |
# | loss_y     | 0.029586     | 0.061138     | 0.084652     |
# | loss_w     | 0.208241     | 0.068984     | 0.111199     |
# | loss_h     | 0.071044     | 0.068326     | 0.104249     |
# | loss_obj   | 2.179631     | 2.302798     | 1.815637     |
# | loss_cls   | 0.025093     | 0.026289     | 0.027194     |
# | cls_acc    | 77.78%       | 78.95%       | 68.42%       |
# | conf_obj   | 0.460634     | 0.500625     | 0.545973     |
# | conf_noobj | 0.006611     | 0.006546     | 0.006943     |
# +------------+--------------+--------------+--------------+
# Total loss 7.407954216003418
# ---- ETA 0:37:34.875591
#  67% 1141/1713 [09:12<03:49,  2.49it/s]
# ---- [Epoch 2/3, Batch 1142/1713] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 16           | 32           | 64           |
# | loss       | 3.415035     | 2.840402     | 2.944885     |
# | loss_x     | 0.066639     | 0.058635     | 0.059211     |
# | loss_y     | 0.048566     | 0.067492     | 0.061636     |
# | loss_w     | 0.253028     | 0.074334     | 0.095474     |
# | loss_h     | 0.132571     | 0.057049     | 0.123115     |
# | loss_obj   | 2.866838     | 2.532910     | 2.550556     |
# | loss_cls   | 0.047393     | 0.049981     | 0.054892     |
# | cls_acc    | 28.00%       | 26.92%       | 22.22%       |
# | conf_obj   | 0.274762     | 0.416299     | 0.366697     |
# | conf_noobj | 0.006298     | 0.006263     | 0.006520     |
# +------------+--------------+--------------+--------------+
# Total loss 9.200322151184082
# ---- ETA 0:11:41.331364
# 100% 1712/1713 [13:36<00:00,  1.85it/s]
# ---- [Epoch 2/3, Batch 1713/1713] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 11           | 22           | 44           |
# | loss       | 2.790106     | 2.068690     | 2.185287     |
# | loss_x     | 0.018700     | 0.100891     | 0.109452     |
# | loss_y     | 0.014276     | 0.050931     | 0.069570     |
# | loss_w     | 0.182620     | 0.133333     | 0.132225     |
# | loss_h     | 0.037151     | 0.061912     | 0.085002     |
# | loss_obj   | 2.495234     | 1.685813     | 1.742464     |
# | loss_cls   | 0.042125     | 0.035809     | 0.046574     |
# | cls_acc    | 28.57%       | 42.86%       | 28.57%       |
# | conf_obj   | 0.309637     | 0.546803     | 0.478241     |
# | conf_noobj | 0.008839     | 0.007722     | 0.006711     |
# +------------+--------------+--------------+--------------+
# Total loss 7.044082164764404
# ---- ETA 0:00:00
# 100% 1713/1713 [13:37<00:00,  2.10it/s]
# Current epoch loss : 9.16086 Saved at checkpoints/Yolo_V3_VOC.pth
# 1713
#  33% 570/1713 [04:36<09:16,  2.05it/s]
# ---- [Epoch 3/3, Batch 571/1713] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 13           | 26           | 52           |
# | loss       | 3.149308     | 3.060311     | 3.021114     |
# | loss_x     | 0.097588     | 0.085975     | 0.081477     |
# | loss_y     | 0.115724     | 0.088348     | 0.088261     |
# | loss_w     | 0.117985     | 0.066993     | 0.048884     |
# | loss_h     | 0.075906     | 0.030145     | 0.087433     |
# | loss_obj   | 2.712186     | 2.756961     | 2.683661     |
# | loss_cls   | 0.029919     | 0.031889     | 0.031399     |
# | cls_acc    | 66.67%       | 66.67%       | 66.67%       |
# | conf_obj   | 0.222121     | 0.225161     | 0.281261     |
# | conf_noobj | 0.006839     | 0.005963     | 0.006309     |
# +------------+--------------+--------------+--------------+
# Total loss 9.230733871459961
# ---- ETA 1:04:48.390295
#  67% 1141/1713 [08:56<04:33,  2.09it/s]
# ---- [Epoch 3/3, Batch 1142/1713] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 10           | 20           | 40           |
# | loss       | 3.861242     | 3.099222     | 3.294529     |
# | loss_x     | 0.076464     | 0.079472     | 0.094732     |
# | loss_y     | 0.033421     | 0.066482     | 0.070883     |
# | loss_w     | 0.290665     | 0.098027     | 0.099818     |
# | loss_h     | 0.128904     | 0.118584     | 0.120954     |
# | loss_obj   | 3.294130     | 2.700149     | 2.868441     |
# | loss_cls   | 0.037657     | 0.036508     | 0.039702     |
# | cls_acc    | 41.18%       | 47.06%       | 47.06%       |
# | conf_obj   | 0.253354     | 0.324495     | 0.284540     |
# | conf_noobj | 0.007906     | 0.006987     | 0.006842     |
# +------------+--------------+--------------+--------------+
# Total loss 10.254993438720703
# ---- ETA 0:18:21.449114
# 100% 1712/1713 [13:30<00:00,  2.07it/s]
# ---- [Epoch 3/3, Batch 1713/1713] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 15           | 30           | 60           |
# | loss       | 2.566991     | 2.322260     | 2.284241     |
# | loss_x     | 0.103740     | 0.061289     | 0.065049     |
# | loss_y     | 0.033210     | 0.044117     | 0.083359     |
# | loss_w     | 0.114256     | 0.171648     | 0.167683     |
# | loss_h     | 0.136107     | 0.030537     | 0.064272     |
# | loss_obj   | 2.144232     | 1.977095     | 1.866333     |
# | loss_cls   | 0.035446     | 0.037575     | 0.037545     |
# | cls_acc    | 46.67%       | 46.67%       | 46.67%       |
# | conf_obj   | 0.385474     | 0.455412     | 0.456317     |
# | conf_noobj | 0.007284     | 0.007544     | 0.006563     |
# +------------+--------------+--------------+--------------+
# Total loss 7.173491477966309
# ---- ETA 0:00:00
# 100% 1713/1713 [13:31<00:00,  2.11it/s]
# Current epoch loss : 9.15130 Saved at checkpoints/Yolo_V3_VOC.pth
#
# ---- Evaluating Model ----
# Detecting objects: 100% 429/429 [01:15<00:00,  5.65it/s]
# Computing AP: 100% 20/20 [00:00<00:00, 832.33it/s]
# +-------+-------------+---------+
# | Index | Class name  | AP      |
# +-------+-------------+---------+
# | 0     | aeroplane   | 0.00269 |
# | 1     | bicycle     | 0.00000 |
# | 2     | bird        | 0.00004 |
# | 3     | boat        | 0.00000 |
# | 4     | bottle      | 0.00000 |
# | 5     | bus         | 0.00000 |
# | 6     | car         | 0.02248 |
# | 7     | cat         | 0.00000 |
# | 8     | chair       | 0.00000 |
# | 9     | cow         | 0.00000 |
# | 10    | diningtable | 0.00000 |
# | 11    | dog         | 0.00000 |
# | 12    | horse       | 0.00000 |
# | 13    | motorbike   | 0.00000 |
# | 14    | person      | 0.38104 |
# | 15    | pottedplant | 0.00000 |
# | 16    | sheep       | 0.00331 |
# | 17    | sofa        | 0.00000 |
# | 18    | train       | 0.00000 |
# | 19    | tvmonitor   | 0.00000 |
# +-------+-------------+---------+
# ---- mAP 0.020478055677741868

# %% [markdown]
# # 12. Train YOLO v3-tiny from Pre-trained Weights

# %%
! python train.py --num_epochs 3 --batch_size 32 --data_config config/VOC.data --model_def config/yolov3-tiny.cfg --pretrained_path checkpoints/Yolo_V3_VOC_tiny.pth --save_path checkpoints/Yolo_V3_VOC_tiny.pth
# Out:
# {'data_config': 'config/VOC.data', 'model_def': 'config/yolov3-tiny.cfg', 'pretrained_path': 'checkpoints/Yolo_V3_VOC_tiny.pth', 'save_path': 'checkpoints/Yolo_V3_VOC_tiny.pth', 'working_dir': './', 'num_epochs': 3, 'batch_size': 32, 'img_size': 416, 'n_cpu': 1, 'gradient_accumulations': 2, 'evaluation_interval': 2, 'multiscale_training': True, 'checkpoint_freq': 2, 'iou_thres': 0.5, 'conf_thres': 0.5, 'nms_thres': 0.5, 'ckpt_dir': './checkpoints', 'logs_dir': './logs'}
# cuda
# checkpoints/Yolo_V3_VOC_tiny.pth
# Trained pytorch weight loaded!
# 429
#  33% 142/429 [00:41<01:20,  3.56it/s]
# ---- [Epoch 1/3, Batch 143/429] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 13           | 26           |
# | loss       | 2.350873     | 2.194032     |
# | loss_x     | 0.049477     | 0.069431     |
# | loss_y     | 0.042964     | 0.064292     |
# | loss_w     | 0.064965     | 0.050604     |
# | loss_h     | 0.066851     | 0.068664     |
# | loss_obj   | 2.110230     | 1.922956     |
# | loss_cls   | 0.016386     | 0.018085     |
# | cls_acc    | 75.51%       | 74.00%       |
# | conf_obj   | 0.461348     | 0.492294     |
# | conf_noobj | 0.006879     | 0.006980     |
# +------------+--------------+--------------+
# Total loss 4.544905185699463
# ---- ETA 0:01:23.028435
#  66% 285/429 [01:21<00:37,  3.79it/s]
# ---- [Epoch 1/3, Batch 286/429] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 11           | 22           |
# | loss       | 2.211456     | 1.932917     |
# | loss_x     | 0.043892     | 0.044697     |
# | loss_y     | 0.039258     | 0.052901     |
# | loss_w     | 0.056332     | 0.057846     |
# | loss_h     | 0.055704     | 0.035035     |
# | loss_obj   | 2.005417     | 1.728604     |
# | loss_cls   | 0.010852     | 0.013834     |
# | cls_acc    | 85.37%       | 81.18%       |
# | conf_obj   | 0.423679     | 0.488677     |
# | conf_noobj | 0.004917     | 0.005067     |
# +------------+--------------+--------------+
# Total loss 4.144372940063477
# ---- ETA 0:00:40.999813
# 100% 428/429 [02:01<00:00,  3.54it/s]
# ---- [Epoch 1/3, Batch 429/429] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 13           | 26           |
# | loss       | 2.724612     | 2.084889     |
# | loss_x     | 0.044370     | 0.028357     |
# | loss_y     | 0.015089     | 0.040903     |
# | loss_w     | 0.024525     | 0.085790     |
# | loss_h     | 0.027876     | 0.030589     |
# | loss_obj   | 2.576083     | 1.859577     |
# | loss_cls   | 0.036668     | 0.039673     |
# | cls_acc    | 36.36%       | 54.55%       |
# | conf_obj   | 0.427099     | 0.491287     |
# | conf_noobj | 0.007902     | 0.006105     |
# +------------+--------------+--------------+
# Total loss 4.809500694274902
# ---- ETA 0:00:00
# 100% 429/429 [02:02<00:00,  3.51it/s]
# Current epoch loss : 4.54285 Saved at checkpoints/Yolo_V3_VOC_tiny.pth
# 429
#  33% 142/429 [00:42<01:17,  3.70it/s]
# ---- [Epoch 2/3, Batch 143/429] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 11           | 22           |
# | loss       | 1.639635     | 1.583956     |
# | loss_x     | 0.036307     | 0.074565     |
# | loss_y     | 0.031736     | 0.061937     |
# | loss_w     | 0.064219     | 0.028399     |
# | loss_h     | 0.028473     | 0.012825     |
# | loss_obj   | 1.461081     | 1.386888     |
# | loss_cls   | 0.017820     | 0.019343     |
# | cls_acc    | 75.00%       | 75.00%       |
# | conf_obj   | 0.546883     | 0.570406     |
# | conf_noobj | 0.005274     | 0.005010     |
# +------------+--------------+--------------+
# Total loss 3.2235913276672363
# ---- ETA 0:05:30.145639
#  66% 285/429 [01:23<00:37,  3.84it/s]
# ---- [Epoch 2/3, Batch 286/429] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 10           | 20           |
# | loss       | 2.431622     | 2.158010     |
# | loss_x     | 0.066064     | 0.074901     |
# | loss_y     | 0.038012     | 0.075485     |
# | loss_w     | 0.080633     | 0.071671     |
# | loss_h     | 0.098520     | 0.054410     |
# | loss_obj   | 2.131860     | 1.865505     |
# | loss_cls   | 0.016532     | 0.016039     |
# | cls_acc    | 75.34%       | 75.64%       |
# | conf_obj   | 0.396562     | 0.440562     |
# | conf_noobj | 0.006038     | 0.005904     |
# +------------+--------------+--------------+
# Total loss 4.589632034301758
# ---- ETA 0:01:42.772741
# 100% 428/429 [02:03<00:00,  3.76it/s]
# ---- [Epoch 2/3, Batch 429/429] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 10           | 20           |
# | loss       | 2.405885     | 2.386630     |
# | loss_x     | 0.045123     | 0.025369     |
# | loss_y     | 0.034243     | 0.049928     |
# | loss_w     | 0.138225     | 0.036204     |
# | loss_h     | 0.083024     | 0.014638     |
# | loss_obj   | 2.082846     | 2.233631     |
# | loss_cls   | 0.022424     | 0.026859     |
# | cls_acc    | 58.33%       | 50.00%       |
# | conf_obj   | 0.387648     | 0.347259     |
# | conf_noobj | 0.006965     | 0.006895     |
# +------------+--------------+--------------+
# Total loss 4.792515754699707
# ---- ETA 0:00:00
# 100% 429/429 [02:03<00:00,  3.46it/s]
# Current epoch loss : 4.25363 Saved at checkpoints/Yolo_V3_VOC_tiny.pth
# 429
#  33% 142/429 [00:41<01:20,  3.55it/s]
# ---- [Epoch 3/3, Batch 143/429] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 13           | 26           |
# | loss       | 1.814289     | 1.746757     |
# | loss_x     | 0.050429     | 0.058581     |
# | loss_y     | 0.039059     | 0.056813     |
# | loss_w     | 0.085227     | 0.044618     |
# | loss_h     | 0.035152     | 0.015643     |
# | loss_obj   | 1.592511     | 1.559036     |
# | loss_cls   | 0.011912     | 0.012066     |
# | cls_acc    | 81.01%       | 79.75%       |
# | conf_obj   | 0.572631     | 0.581520     |
# | conf_noobj | 0.005627     | 0.005790     |
# +------------+--------------+--------------+
# Total loss 3.5610461235046387
# ---- ETA 0:09:35.706108
#  66% 285/429 [01:21<00:43,  3.34it/s]
# ---- [Epoch 3/3, Batch 286/429] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 14           | 28           |
# | loss       | 2.080220     | 2.028697     |
# | loss_x     | 0.059785     | 0.085567     |
# | loss_y     | 0.042476     | 0.069714     |
# | loss_w     | 0.044777     | 0.044789     |
# | loss_h     | 0.029057     | 0.033321     |
# | loss_obj   | 1.889795     | 1.779747     |
# | loss_cls   | 0.014331     | 0.015559     |
# | cls_acc    | 80.25%       | 80.72%       |
# | conf_obj   | 0.464070     | 0.477859     |
# | conf_noobj | 0.006178     | 0.005740     |
# +------------+--------------+--------------+
# Total loss 4.108917713165283
# ---- ETA 0:02:44.047436
# 100% 428/429 [02:01<00:00,  3.58it/s]
# ---- [Epoch 3/3, Batch 429/429] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 13           | 26           |
# | loss       | 2.546044     | 2.662402     |
# | loss_x     | 0.037644     | 0.075249     |
# | loss_y     | 0.072736     | 0.029706     |
# | loss_w     | 0.031453     | 0.067557     |
# | loss_h     | 0.012298     | 0.025715     |
# | loss_obj   | 2.377162     | 2.440980     |
# | loss_cls   | 0.014751     | 0.023195     |
# | cls_acc    | 71.43%       | 57.14%       |
# | conf_obj   | 0.445093     | 0.244999     |
# | conf_noobj | 0.005642     | 0.004984     |
# +------------+--------------+--------------+
# Total loss 5.208446502685547
# ---- ETA 0:00:00
# 100% 429/429 [02:01<00:00,  3.54it/s]
# Current epoch loss : 4.27729 Saved at checkpoints/Yolo_V3_VOC_tiny.pth
#
# ---- Evaluating Model ----
# Detecting objects: 100% 108/108 [00:29<00:00,  3.71it/s]
# Computing AP: 100% 20/20 [00:00<00:00, 724.95it/s]
# +-------+-------------+---------+
# | Index | Class name  | AP      |
# +-------+-------------+---------+
# | 0     | aeroplane   | 0.34026 |
# | 1     | bicycle     | 0.25314 |
# | 2     | bird        | 0.11319 |
# | 3     | boat        | 0.08592 |
# | 4     | bottle      | 0.12900 |
# | 5     | bus         | 0.37386 |
# | 6     | car         | 0.27014 |
# | 7     | cat         | 0.27359 |
# | 8     | chair       | 0.16042 |
# | 9     | cow         | 0.08104 |
# | 10    | diningtable | 0.09048 |
# | 11    | dog         | 0.18667 |
# | 12    | horse       | 0.10554 |
# | 13    | motorbike   | 0.22747 |
# | 14    | person      | 0.46373 |
# | 15    | pottedplant | 0.09536 |
# | 16    | sheep       | 0.18952 |
# | 17    | sofa        | 0.19152 |
# | 18    | train       | 0.29076 |
# | 19    | tvmonitor   | 0.38244 |
# +-------+-------------+---------+
# ---- mAP 0.21520262246779542

# %% [markdown]
# # 13. Train YOLO v3-tiny from Darknet Weights

# %%
! python train.py --num_epochs 8 --batch_size 32 --data_config config/VOC.data --model_def config/yolov3-tiny.cfg --pretrained_path checkpoints/yolov3-tiny.weights --save_path checkpoints/Yolo_V3_VOC_tiny.pth
# Out:
# {'data_config': 'config/VOC.data', 'model_def': 'config/yolov3-tiny.cfg', 'pretrained_path': 'checkpoints/yolov3-tiny.weights', 'save_path': 'checkpoints/Yolo_V3_VOC_tiny.pth', 'working_dir': './', 'num_epochs': 8, 'batch_size': 32, 'img_size': 416, 'n_cpu': 1, 'gradient_accumulations': 2, 'evaluation_interval': 2, 'multiscale_training': True, 'checkpoint_freq': 2, 'iou_thres': 0.5, 'conf_thres': 0.5, 'nms_thres': 0.5, 'ckpt_dir': './checkpoints', 'logs_dir': './logs'}
# cuda
# checkpoints/yolov3-tiny.weights
# Darknet weight loaded!
# 429
#  33% 142/429 [00:41<01:15,  3.80it/s]
# ---- [Epoch 1/8, Batch 143/429] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 12           | 24           |
# | loss       | 3.013657     | 2.697237     |
# | loss_x     | 0.061604     | 0.075887     |
# | loss_y     | 0.059232     | 0.070295     |
# | loss_w     | 0.256039     | 0.074647     |
# | loss_h     | 0.081630     | 0.057203     |
# | loss_obj   | 2.520524     | 2.372030     |
# | loss_cls   | 0.034629     | 0.047175     |
# | cls_acc    | 54.05%       | 35.14%       |
# | conf_obj   | 0.272638     | 0.305731     |
# | conf_noobj | 0.006028     | 0.006501     |
# +------------+--------------+--------------+
# Total loss 5.710894584655762
# ---- ETA 0:01:24.144000
#  66% 285/429 [01:22<00:39,  3.65it/s]
# ---- [Epoch 1/8, Batch 286/429] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 10           | 20           |
# | loss       | 3.641343     | 3.111585     |
# | loss_x     | 0.062009     | 0.058701     |
# | loss_y     | 0.043374     | 0.063044     |
# | loss_w     | 0.216946     | 0.086022     |
# | loss_h     | 0.124728     | 0.065586     |
# | loss_obj   | 3.161410     | 2.803737     |
# | loss_cls   | 0.032876     | 0.034496     |
# | cls_acc    | 54.05%       | 49.33%       |
# | conf_obj   | 0.269673     | 0.304827     |
# | conf_noobj | 0.006860     | 0.006692     |
# +------------+--------------+--------------+
# Total loss 6.752928733825684
# ---- ETA 0:00:41.476413
# 100% 428/429 [02:02<00:00,  3.65it/s]
# ---- [Epoch 1/8, Batch 429/429] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 13           | 26           |
# | loss       | 3.179237     | 3.275195     |
# | loss_x     | 0.054631     | 0.053754     |
# | loss_y     | 0.079374     | 0.069066     |
# | loss_w     | 0.159584     | 0.173409     |
# | loss_h     | 0.043752     | 0.359265     |
# | loss_obj   | 2.795441     | 2.551569     |
# | loss_cls   | 0.046455     | 0.068131     |
# | cls_acc    | 23.08%       | 14.29%       |
# | conf_obj   | 0.373738     | 0.411377     |
# | conf_noobj | 0.005192     | 0.006939     |
# +------------+--------------+--------------+
# Total loss 6.454432010650635
# ---- ETA 0:00:00
# 100% 429/429 [02:03<00:00,  3.48it/s]
# Current epoch loss : 6.25524 Saved at checkpoints/Yolo_V3_VOC_tiny.pth
# 429
#  33% 142/429 [00:38<01:15,  3.81it/s]
# ---- [Epoch 2/8, Batch 143/429] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 12           | 24           |
# | loss       | 3.520496     | 3.137408     |
# | loss_x     | 0.055605     | 0.060578     |
# | loss_y     | 0.053230     | 0.058070     |
# | loss_w     | 0.207056     | 0.092808     |
# | loss_h     | 0.160575     | 0.060626     |
# | loss_obj   | 3.017520     | 2.831217     |
# | loss_cls   | 0.026509     | 0.034109     |
# | cls_acc    | 62.89%       | 50.00%       |
# | conf_obj   | 0.243024     | 0.260493     |
# | conf_noobj | 0.007087     | 0.007361     |
# +------------+--------------+--------------+
# Total loss 6.657903671264648
# ---- ETA 0:05:25.111932
#  66% 285/429 [01:19<00:36,  3.92it/s]
# ---- [Epoch 2/8, Batch 286/429] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 11           | 22           |
# | loss       | 2.667064     | 2.764039     |
# | loss_x     | 0.075019     | 0.073904     |
# | loss_y     | 0.030246     | 0.058340     |
# | loss_w     | 0.163344     | 0.140268     |
# | loss_h     | 0.076306     | 0.060415     |
# | loss_obj   | 2.295761     | 2.401234     |
# | loss_cls   | 0.026389     | 0.029878     |
# | cls_acc    | 65.00%       | 53.66%       |
# | conf_obj   | 0.335472     | 0.335184     |
# | conf_noobj | 0.006213     | 0.006904     |
# +------------+--------------+--------------+
# Total loss 5.431102752685547
# ---- ETA 0:01:41.280527
# 100% 428/429 [01:57<00:00,  3.59it/s]
# ---- [Epoch 2/8, Batch 429/429] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 14           | 28           |
# | loss       | 3.248981     | 2.905285     |
# | loss_x     | 0.062878     | 0.025530     |
# | loss_y     | 0.075114     | 0.079323     |
# | loss_w     | 0.041780     | 0.112237     |
# | loss_h     | 0.021245     | 0.024580     |
# | loss_obj   | 3.015908     | 2.631734     |
# | loss_cls   | 0.032056     | 0.031881     |
# | cls_acc    | 45.45%       | 45.45%       |
# | conf_obj   | 0.302764     | 0.279224     |
# | conf_noobj | 0.008320     | 0.006678     |
# +------------+--------------+--------------+
# Total loss 6.154265880584717
# ---- ETA 0:00:00
# 100% 429/429 [01:58<00:00,  3.63it/s]
# Current epoch loss : 5.64563 Saved at checkpoints/Yolo_V3_VOC_tiny.pth
# 429
#  33% 142/429 [00:38<01:27,  3.27it/s]
# ---- [Epoch 3/8, Batch 143/429] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 16           | 32           |
# | loss       | 2.694753     | 2.619846     |
# | loss_x     | 0.055142     | 0.068634     |
# | loss_y     | 0.054348     | 0.073808     |
# | loss_w     | 0.046922     | 0.071879     |
# | loss_h     | 0.039615     | 0.083531     |
# | loss_obj   | 2.477305     | 2.293003     |
# | loss_cls   | 0.021421     | 0.028991     |
# | cls_acc    | 66.67%       | 61.67%       |
# | conf_obj   | 0.328068     | 0.371681     |
# | conf_noobj | 0.006786     | 0.006383     |
# +------------+--------------+--------------+
# Total loss 5.314599514007568
# ---- ETA 0:09:21.776562
#  66% 285/429 [01:18<00:37,  3.83it/s]
# ---- [Epoch 3/8, Batch 286/429] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 12           | 24           |
# | loss       | 3.071079     | 3.133797     |
# | loss_x     | 0.070791     | 0.072714     |
# | loss_y     | 0.048609     | 0.074168     |
# | loss_w     | 0.170074     | 0.128421     |
# | loss_h     | 0.091043     | 0.090880     |
# | loss_obj   | 2.660927     | 2.731369     |
# | loss_cls   | 0.029634     | 0.036246     |
# | cls_acc    | 54.02%       | 43.16%       |
# | conf_obj   | 0.325542     | 0.297109     |
# | conf_noobj | 0.006863     | 0.006859     |
# +------------+--------------+--------------+
# Total loss 6.204875946044922
# ---- ETA 0:02:40.222600
# 100% 428/429 [01:58<00:00,  3.53it/s]
# ---- [Epoch 3/8, Batch 429/429] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 14           | 28           |
# | loss       | 1.595188     | 1.511643     |
# | loss_x     | 0.032492     | 0.038891     |
# | loss_y     | 0.026000     | 0.044299     |
# | loss_w     | 0.053151     | 0.035487     |
# | loss_h     | 0.050688     | 0.039695     |
# | loss_obj   | 1.391220     | 1.301148     |
# | loss_cls   | 0.041638     | 0.052124     |
# | cls_acc    | 45.45%       | 45.45%       |
# | conf_obj   | 0.570990     | 0.705580     |
# | conf_noobj | 0.005273     | 0.006775     |
# +------------+--------------+--------------+
# Total loss 3.1068308353424072
# ---- ETA 0:00:00
# 100% 429/429 [01:58<00:00,  3.62it/s]
# Current epoch loss : 5.67239 Saved at checkpoints/Yolo_V3_VOC_tiny.pth
# 429
#  33% 142/429 [00:39<01:12,  3.95it/s]
# ---- [Epoch 4/8, Batch 143/429] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 10           | 20           |
# | loss       | 3.096575     | 2.778710     |
# | loss_x     | 0.043724     | 0.059106     |
# | loss_y     | 0.043477     | 0.061818     |
# | loss_w     | 0.089925     | 0.053837     |
# | loss_h     | 0.062490     | 0.038590     |
# | loss_obj   | 2.826002     | 2.529017     |
# | loss_cls   | 0.030956     | 0.036344     |
# | cls_acc    | 55.74%       | 44.26%       |
# | conf_obj   | 0.287599     | 0.283781     |
# | conf_noobj | 0.006517     | 0.006190     |
# +------------+--------------+--------------+
# Total loss 5.8752851486206055
# ---- ETA 0:13:18.749902
#  66% 285/429 [01:17<00:36,  3.95it/s]
# ---- [Epoch 4/8, Batch 286/429] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 11           | 22           |
# | loss       | 3.245094     | 2.724265     |
# | loss_x     | 0.043236     | 0.060373     |
# | loss_y     | 0.040909     | 0.048805     |
# | loss_w     | 0.214383     | 0.152151     |
# | loss_h     | 0.089571     | 0.098812     |
# | loss_obj   | 2.828235     | 2.328441     |
# | loss_cls   | 0.028759     | 0.035683     |
# | cls_acc    | 53.52%       | 45.21%       |
# | conf_obj   | 0.320446     | 0.378108     |
# | conf_noobj | 0.007082     | 0.006932     |
# +------------+--------------+--------------+
# Total loss 5.969358921051025
# ---- ETA 0:03:38.838608
# 100% 428/429 [01:56<00:00,  3.34it/s]
# ---- [Epoch 4/8, Batch 429/429] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 15           | 30           |
# | loss       | 2.684764     | 2.711644     |
# | loss_x     | 0.063157     | 0.097584     |
# | loss_y     | 0.052942     | 0.088555     |
# | loss_w     | 0.009550     | 0.050575     |
# | loss_h     | 0.016845     | 0.073302     |
# | loss_obj   | 2.518510     | 2.377976     |
# | loss_cls   | 0.023760     | 0.023652     |
# | cls_acc    | 75.00%       | 75.00%       |
# | conf_obj   | 0.313583     | 0.253206     |
# | conf_noobj | 0.006186     | 0.005689     |
# +------------+--------------+--------------+
# Total loss 5.396407604217529
# ---- ETA 0:00:00
# 100% 429/429 [01:57<00:00,  3.67it/s]
# Current epoch loss : 5.69858 Saved at checkpoints/Yolo_V3_VOC_tiny.pth
# 429
#  33% 142/429 [00:40<01:18,  3.64it/s]
# ---- [Epoch 5/8, Batch 143/429] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 14           | 28           |
# | loss       | 2.836506     | 2.774708     |
# | loss_x     | 0.071690     | 0.070437     |
# | loss_y     | 0.061365     | 0.078960     |
# | loss_w     | 0.123500     | 0.070943     |
# | loss_h     | 0.078636     | 0.112045     |
# | loss_obj   | 2.467838     | 2.399261     |
# | loss_cls   | 0.033477     | 0.043061     |
# | cls_acc    | 45.76%       | 37.29%       |
# | conf_obj   | 0.328902     | 0.351953     |
# | conf_noobj | 0.006610     | 0.006470     |
# +------------+--------------+--------------+
# Total loss 5.611213684082031
# ---- ETA 0:17:15.579525
#  66% 285/429 [01:19<00:38,  3.77it/s]
# ---- [Epoch 5/8, Batch 286/429] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 11           | 22           |
# | loss       | 3.130434     | 2.890348     |
# | loss_x     | 0.071780     | 0.089029     |
# | loss_y     | 0.054613     | 0.062847     |
# | loss_w     | 0.246517     | 0.229806     |
# | loss_h     | 0.070809     | 0.054771     |
# | loss_obj   | 2.655903     | 2.413826     |
# | loss_cls   | 0.030811     | 0.040069     |
# | cls_acc    | 50.00%       | 41.25%       |
# | conf_obj   | 0.278864     | 0.284236     |
# | conf_noobj | 0.006638     | 0.006237     |
# +------------+--------------+--------------+
# Total loss 6.020781993865967
# ---- ETA 0:04:38.469353
# 100% 428/429 [01:58<00:00,  3.83it/s]
# ---- [Epoch 5/8, Batch 429/429] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 11           | 22           |
# | loss       | 3.564568     | 4.016983     |
# | loss_x     | 0.050245     | 0.056726     |
# | loss_y     | 0.024765     | 0.071328     |
# | loss_w     | 0.108351     | 0.084539     |
# | loss_h     | 0.055010     | 0.029528     |
# | loss_obj   | 3.292132     | 3.734284     |
# | loss_cls   | 0.034064     | 0.040576     |
# | cls_acc    | 46.67%       | 33.33%       |
# | conf_obj   | 0.213772     | 0.202557     |
# | conf_noobj | 0.006432     | 0.007513     |
# +------------+--------------+--------------+
# Total loss 7.581550598144531
# ---- ETA 0:00:00
# 100% 429/429 [01:58<00:00,  3.63it/s]
# Current epoch loss : 5.63388 Saved at checkpoints/Yolo_V3_VOC_tiny.pth
# 429
#  33% 142/429 [00:38<01:20,  3.59it/s]
# ---- [Epoch 6/8, Batch 143/429] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 13           | 26           |
# | loss       | 2.922130     | 2.806909     |
# | loss_x     | 0.055226     | 0.054138     |
# | loss_y     | 0.038406     | 0.074923     |
# | loss_w     | 0.077393     | 0.062965     |
# | loss_h     | 0.104425     | 0.076056     |
# | loss_obj   | 2.607509     | 2.488999     |
# | loss_cls   | 0.039171     | 0.049828     |
# | cls_acc    | 31.88%       | 26.76%       |
# | conf_obj   | 0.318058     | 0.308733     |
# | conf_noobj | 0.006755     | 0.006545     |
# +------------+--------------+--------------+
# Total loss 5.729039192199707
# ---- ETA 0:21:08.617150
#  66% 285/429 [01:17<00:36,  3.94it/s]
# ---- [Epoch 6/8, Batch 286/429] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 10           | 20           |
# | loss       | 2.617860     | 2.558154     |
# | loss_x     | 0.048871     | 0.069039     |
# | loss_y     | 0.050488     | 0.069234     |
# | loss_w     | 0.069690     | 0.084560     |
# | loss_h     | 0.058743     | 0.049222     |
# | loss_obj   | 2.363098     | 2.251076     |
# | loss_cls   | 0.026969     | 0.035022     |
# | cls_acc    | 57.14%       | 53.57%       |
# | conf_obj   | 0.355451     | 0.353019     |
# | conf_noobj | 0.006982     | 0.006953     |
# +------------+--------------+--------------+
# Total loss 5.176013946533203
# ---- ETA 0:05:36.797928
# 100% 428/429 [01:56<00:00,  3.84it/s]
# ---- [Epoch 6/8, Batch 429/429] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 12           | 24           |
# | loss       | 3.000716     | 2.246122     |
# | loss_x     | 0.111577     | 0.063624     |
# | loss_y     | 0.039361     | 0.131887     |
# | loss_w     | 0.113773     | 0.122165     |
# | loss_h     | 0.016287     | 0.048897     |
# | loss_obj   | 2.697361     | 1.850500     |
# | loss_cls   | 0.022356     | 0.029049     |
# | cls_acc    | 60.00%       | 60.00%       |
# | conf_obj   | 0.324941     | 0.369165     |
# | conf_noobj | 0.007238     | 0.006821     |
# +------------+--------------+--------------+
# Total loss 5.246838569641113
# ---- ETA 0:00:00
# 100% 429/429 [01:56<00:00,  3.67it/s]
# Current epoch loss : 5.68153 Saved at checkpoints/Yolo_V3_VOC_tiny.pth
# 429
#  33% 142/429 [00:39<01:14,  3.84it/s]
# ---- [Epoch 7/8, Batch 143/429] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 10           | 20           |
# | loss       | 3.081990     | 2.839354     |
# | loss_x     | 0.067724     | 0.068499     |
# | loss_y     | 0.048544     | 0.081303     |
# | loss_w     | 0.114293     | 0.087385     |
# | loss_h     | 0.112871     | 0.069732     |
# | loss_obj   | 2.709173     | 2.495687     |
# | loss_cls   | 0.029385     | 0.036747     |
# | cls_acc    | 54.93%       | 41.10%       |
# | conf_obj   | 0.294780     | 0.320611     |
# | conf_noobj | 0.006970     | 0.006931     |
# +------------+--------------+--------------+
# Total loss 5.92134428024292
# ---- ETA 0:25:04.578865
#  66% 285/429 [01:19<00:39,  3.62it/s]
# ---- [Epoch 7/8, Batch 286/429] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 14           | 28           |
# | loss       | 2.817373     | 2.677450     |
# | loss_x     | 0.056906     | 0.073677     |
# | loss_y     | 0.070010     | 0.082700     |
# | loss_w     | 0.096292     | 0.118778     |
# | loss_h     | 0.085314     | 0.084850     |
# | loss_obj   | 2.480270     | 2.279349     |
# | loss_cls   | 0.028582     | 0.038095     |
# | cls_acc    | 56.58%       | 41.03%       |
# | conf_obj   | 0.338329     | 0.359920     |
# | conf_noobj | 0.006920     | 0.006966     |
# +------------+--------------+--------------+
# Total loss 5.494822978973389
# ---- ETA 0:06:36.306131
# 100% 428/429 [02:00<00:00,  3.85it/s]
# ---- [Epoch 7/8, Batch 429/429] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 11           | 22           |
# | loss       | 4.201655     | 4.526803     |
# | loss_x     | 0.093454     | 0.077990     |
# | loss_y     | 0.069119     | 0.094332     |
# | loss_w     | 0.681319     | 0.473474     |
# | loss_h     | 0.187533     | 0.159120     |
# | loss_obj   | 3.127208     | 3.660189     |
# | loss_cls   | 0.043022     | 0.061697     |
# | cls_acc    | 14.29%       | 8.33%        |
# | conf_obj   | 0.161678     | 0.200985     |
# | conf_noobj | 0.008469     | 0.008522     |
# +------------+--------------+--------------+
# Total loss 8.728458404541016
# ---- ETA 0:00:00
# 100% 429/429 [02:00<00:00,  3.56it/s]
# Current epoch loss : 5.66406 Saved at checkpoints/Yolo_V3_VOC_tiny.pth
# 429
#  33% 142/429 [00:40<01:24,  3.41it/s]
# ---- [Epoch 8/8, Batch 143/429] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 16           | 32           |
# | loss       | 2.316001     | 2.558988     |
# | loss_x     | 0.046781     | 0.068004     |
# | loss_y     | 0.061432     | 0.070755     |
# | loss_w     | 0.073889     | 0.042666     |
# | loss_h     | 0.067223     | 0.047897     |
# | loss_obj   | 2.031398     | 2.290410     |
# | loss_cls   | 0.035278     | 0.039256     |
# | cls_acc    | 48.57%       | 47.14%       |
# | conf_obj   | 0.411574     | 0.330512     |
# | conf_noobj | 0.006337     | 0.006034     |
# +------------+--------------+--------------+
# Total loss 4.8749895095825195
# ---- ETA 0:29:07.961299
#  66% 285/429 [01:20<00:38,  3.75it/s]
# ---- [Epoch 8/8, Batch 286/429] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 11           | 22           |
# | loss       | 3.181802     | 3.044183     |
# | loss_x     | 0.064280     | 0.083044     |
# | loss_y     | 0.063287     | 0.064212     |
# | loss_w     | 0.163634     | 0.084454     |
# | loss_h     | 0.124774     | 0.042983     |
# | loss_obj   | 2.734967     | 2.735026     |
# | loss_cls   | 0.030860     | 0.034463     |
# | cls_acc    | 47.78%       | 53.68%       |
# | conf_obj   | 0.280165     | 0.247615     |
# | conf_noobj | 0.006744     | 0.006933     |
# +------------+--------------+--------------+
# Total loss 6.225984573364258
# ---- ETA 0:07:36.782924
# 100% 428/429 [01:59<00:00,  3.39it/s]
# ---- [Epoch 8/8, Batch 429/429] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 15           | 30           |
# | loss       | 3.710568     | 2.562313     |
# | loss_x     | 0.054870     | 0.067114     |
# | loss_y     | 0.049506     | 0.068767     |
# | loss_w     | 0.012001     | 0.077798     |
# | loss_h     | 0.056596     | 0.214542     |
# | loss_obj   | 3.498683     | 2.079381     |
# | loss_cls   | 0.038911     | 0.054710     |
# | cls_acc    | 60.00%       | 20.00%       |
# | conf_obj   | 0.369223     | 0.436749     |
# | conf_noobj | 0.005971     | 0.006420     |
# +------------+--------------+--------------+
# Total loss 6.272880554199219
# ---- ETA 0:00:00
# 100% 429/429 [02:00<00:00,  3.57it/s]
# Current epoch loss : 5.66776 Saved at checkpoints/Yolo_V3_VOC_tiny.pth
#
# ---- Evaluating Model ----
# Detecting objects: 100% 108/108 [00:28<00:00,  3.78it/s]
# Computing AP: 100% 20/20 [00:00<00:00, 652.04it/s]
# +-------+-------------+---------+
# | Index | Class name  | AP      |
# +-------+-------------+---------+
# | 0     | aeroplane   | 0.02410 |
# | 1     | bicycle     | 0.19135 |
# | 2     | bird        | 0.00000 |
# | 3     | boat        | 0.00000 |
# | 4     | bottle      | 0.00000 |
# | 5     | bus         | 0.20230 |
# | 6     | car         | 0.07122 |
# | 7     | cat         | 0.03636 |
# | 8     | chair       | 0.09760 |
# | 9     | cow         | 0.00000 |
# | 10    | diningtable | 0.00351 |
# | 11    | dog         | 0.03530 |
# | 12    | horse       | 0.00000 |
# | 13    | motorbike   | 0.04100 |
# | 14    | person      | 0.39027 |
# | 15    | pottedplant | 0.00253 |
# | 16    | sheep       | 0.06186 |
# | 17    | sofa        | 0.00898 |
# | 18    | train       | 0.00000 |
# | 19    | tvmonitor   | 0.06172 |
# +-------+-------------+---------+
# ---- mAP 0.06140441650987245
