# %% [markdown]
# # 1. [Opt] Check GPU Type

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
    print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
    print('and then re-execute this cell.')
else:
    print(gpu_info)
# Out:
# Thu Dec  8 03:32:03 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P0    26W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # 2. Git Clone from Github Repository to root directory
# At Colab, location is "/content/".
#
# Using `$ git clone https://github.com/lainyzine/git-clone.git` will load the Github repository with the name of the repository. With Colab, it can be convenient to work in the root directory. You can use the command to call the root directory as shown below.
#
# According to the Github repository, we can use `! git pull origin main` or `! Just use git pull origin master`.

# %%
# Clone from Github Repository
! git init .
! git remote add origin https://github.com/RichardMinsooGo-ML/Bible_3_21_Pytorch_YOLO_v3_Image.git
# ! git pull origin master
! git pull origin main
# Out:
# Initialized empty Git repository in /content/.git/
# remote: Enumerating objects: 1948, done.
# remote: Counting objects: 100% (89/89), done.
# remote: Compressing objects: 100% (86/86), done.
# remote: Total 1948 (delta 49), reused 2 (delta 2), pack-reused 1859
# Receiving objects: 100% (1948/1948), 58.68 MiB | 50.20 MiB/s, done.
# Resolving deltas: 100% (806/806), done.
# From https://github.com/RichardMinsooGo-ML/Bible_3_21_Pytorch_YOLO_v3_Image
#  * branch            main       -> FETCH_HEAD
#  * [new branch]      main       -> origin/main

# %% [markdown]
# # 3. import clear_output

# %%
from IPython.display import clear_output 
clear_output()

# %% [markdown]
# # 4. Mini-COCO dataset download from Auther's Github repository

# %%
# !pip install --upgrade --no-cache-dir gdown

import gdown
google_path = 'https://drive.google.com/uc?id='
file_id = '1jtLdG1SNFo54m8EC_3xYt-gDQQKsNCBR'
output_name = 'coco_10K.zip'
gdown.download(google_path+file_id,output_name,quiet=False)
# https://drive.google.com/file/d/1jtLdG1SNFo54m8EC_3xYt-gDQQKsNCBR/view?usp=sharing

# !unzip /content/coco_10K.zip -d /content/dataset/COCO2017
clear_output()
! rm /content/coco_10K.zip

# %% [markdown]
# # 5. [Opt] Check Memory Space

# %%
# Memory Space
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
    print('To enable a high-RAM runtime, select the Runtime > "Change runtime type"')
    print('menu, and then select High-RAM in the Runtime shape dropdown. Then, ')
    print('re-execute this cell.')
else:
    print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 27.3 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %% [markdown]
# # 6. install terminaltables for Ascii Table print

# %%
# !pip install terminaltables
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting terminaltables
#   Downloading terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Installing collected packages: terminaltables
# Successfully installed terminaltables-3.1.10

# %% [markdown]
# # 7. Download Darknet Weights

# %%
# Download Darknet Weights
# ! wget https://pjreddie.com/media/files/yolo-voc.weights 
! wget https://pjreddie.com/media/files/yolov3-tiny.weights 
! wget https://pjreddie.com/media/files/yolov3.weights
# ! wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v3_optimal/yolov4.weights 
# ! wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v4_pre/yolov4-tiny.weights

import shutil
shutil.move("/content/yolov3-tiny.weights", "/content/checkpoints")
shutil.move("/content/yolov3.weights", "/content/checkpoints")
# shutil.move("/content/yolov4-tiny.weights", "/content/tmp")
# shutil.move("/content/yolov4.weights", "/content/tmp") 
shutil.rmtree("sample_data")
# Out:
# --2022-12-08 03:32:54--  https://pjreddie.com/media/files/yolov3-tiny.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35434956 (34M) [application/octet-stream]
# Saving to: ‘yolov3-tiny.weights’
#
# yolov3-tiny.weights 100%[===================>]  33.79M  27.1MB/s    in 1.2s
#
# 2022-12-08 03:32:55 (27.1 MB/s) - ‘yolov3-tiny.weights’ saved [35434956/35434956]
#
# --2022-12-08 03:32:56--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  33.9MB/s    in 7.5s
#
# 2022-12-08 03:33:03 (31.7 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %% [markdown]
# # 8. YOLO v3 Pre-Trained Weight gdown from Auther's GDrive

# %%
google_path = 'https://drive.google.com/uc?id='
file_id = '1NpwqosGph1uJrb2YbJ_EzR5R917tSZhb'
output_name = 'Yolo_V3_coco.pth'
gdown.download(google_path+file_id,output_name,quiet=False)
# https://drive.google.com/file/d/1NpwqosGph1uJrb2YbJ_EzR5R917tSZhb/view?usp=sharing

shutil.move("/content/Yolo_V3_coco.pth", "./checkpoints")
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1NpwqosGph1uJrb2YbJ_EzR5R917tSZhb
# To: /content/Yolo_V3_coco.pth
# 100%|██████████| 248M/248M [00:01<00:00, 124MB/s]
# './checkpoints/Yolo_V3_coco.pth'

# %% [markdown]
# # 9. YOLO v3-tiny Pre-Trained Weight gdown from Auther's GDrive

# %%
google_path = 'https://drive.google.com/uc?id='
file_id = '1DIxPr1V3c12U-0n9d4ZJulOdiHq7EaN5'
output_name = 'Yolo_V3_coco_tiny.pth'
gdown.download(google_path+file_id,output_name,quiet=False)
# https://drive.google.com/file/d/1DIxPr1V3c12U-0n9d4ZJulOdiHq7EaN5/view?usp=sharing

shutil.move("/content/Yolo_V3_coco_tiny.pth", "./checkpoints")
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1DIxPr1V3c12U-0n9d4ZJulOdiHq7EaN5
# To: /content/Yolo_V3_coco_tiny.pth
# 100%|██████████| 35.5M/35.5M [00:00<00:00, 59.4MB/s]
# './checkpoints/Yolo_V3_coco_tiny.pth'

# %%
# from google.colab import drive 
# drive.mount('/content/gdrive/')

# %% [markdown]
# # 10. Train YOLO v3 from Pre-trained Weights

# %%
! python train.py --num_epochs 3 --batch_size 8 --data_config config/coco.data --model_def config/yolov3.cfg --pretrained_path checkpoints/Yolo_V3_coco.pth --save_path checkpoints/Yolo_V3_coco.pth
# Out:
# {'data_config': 'config/coco.data', 'model_def': 'config/yolov3.cfg', 'pretrained_path': 'checkpoints/Yolo_V3_coco.pth', 'save_path': 'checkpoints/Yolo_V3_coco.pth', 'working_dir': './', 'num_epochs': 3, 'batch_size': 8, 'img_size': 416, 'n_cpu': 1, 'gradient_accumulations': 2, 'evaluation_interval': 2, 'multiscale_training': True, 'checkpoint_freq': 2, 'iou_thres': 0.5, 'conf_thres': 0.5, 'nms_thres': 0.5, 'ckpt_dir': './checkpoints', 'logs_dir': './logs'}
# cuda
# checkpoints/Yolo_V3_coco.pth
# Trained pytorch weight loaded!
# 1304
#  33% 433/1304 [03:29<07:07,  2.04it/s]
# ---- [Epoch 1/3, Batch 434/1304] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 13           | 26           | 52           |
# | loss       | 3.829408     | 3.474049     | 3.349959     |
# | loss_x     | 0.086675     | 0.078247     | 0.074991     |
# | loss_y     | 0.060903     | 0.063111     | 0.071614     |
# | loss_w     | 0.499669     | 0.303769     | 0.294724     |
# | loss_h     | 0.355062     | 0.185191     | 0.152238     |
# | loss_obj   | 2.771190     | 2.790949     | 2.707442     |
# | loss_cls   | 0.055909     | 0.052782     | 0.048950     |
# | cls_acc    | 24.29%       | 27.91%       | 32.98%       |
# | conf_obj   | 0.248879     | 0.271234     | 0.308934     |
# | conf_noobj | 0.007824     | 0.008210     | 0.008174     |
# +------------+--------------+--------------+--------------+
# Total loss 10.65341567993164
# ---- ETA 0:07:00.804324
#  66% 867/1304 [06:46<02:38,  2.76it/s]
# ---- [Epoch 1/3, Batch 868/1304] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 10           | 20           | 40           |
# | loss       | 5.387605     | 4.689153     | 3.931560     |
# | loss_x     | 0.076612     | 0.070134     | 0.065535     |
# | loss_y     | 0.084698     | 0.065877     | 0.049376     |
# | loss_w     | 1.231202     | 0.717561     | 0.466656     |
# | loss_h     | 1.048046     | 0.703367     | 0.373508     |
# | loss_obj   | 2.900012     | 3.089640     | 2.933738     |
# | loss_cls   | 0.047035     | 0.042573     | 0.042746     |
# | cls_acc    | 42.86%       | 45.31%       | 50.68%       |
# | conf_obj   | 0.175918     | 0.264884     | 0.300125     |
# | conf_noobj | 0.007014     | 0.007705     | 0.007654     |
# +------------+--------------+--------------+--------------+
# Total loss 14.008317947387695
# ---- ETA 0:03:24.504787
# 100% 1301/1304 [10:08<00:01,  1.72it/s]
# ---- [Epoch 1/3, Batch 1302/1304] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 11           | 22           | 44           |
# | loss       | 4.613832     | 3.672909     | 3.713684     |
# | loss_x     | 0.068696     | 0.083430     | 0.077212     |
# | loss_y     | 0.064310     | 0.070570     | 0.063112     |
# | loss_w     | 0.594839     | 0.111022     | 0.196705     |
# | loss_h     | 0.478410     | 0.202236     | 0.124013     |
# | loss_obj   | 3.337173     | 3.135818     | 3.177685     |
# | loss_cls   | 0.070405     | 0.069833     | 0.074957     |
# | cls_acc    | 12.00%       | 9.09%        | 10.26%       |
# | conf_obj   | 0.198790     | 0.221897     | 0.175406     |
# | conf_noobj | 0.008330     | 0.008119     | 0.007489     |
# +------------+--------------+--------------+--------------+
# Total loss 12.000425338745117
# ---- ETA 0:00:00.934535
# 100% 1304/1304 [10:08<00:00,  2.14it/s]
# Current epoch loss : 12.73243 Saved at checkpoints/Yolo_V3_coco.pth
# 1304
#  33% 433/1304 [03:31<06:52,  2.11it/s]
# ---- [Epoch 2/3, Batch 434/1304] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 12           | 24           | 48           |
# | loss       | 4.075066     | 3.635070     | 3.582357     |
# | loss_x     | 0.070711     | 0.056238     | 0.082015     |
# | loss_y     | 0.090594     | 0.082627     | 0.079796     |
# | loss_w     | 0.510359     | 0.238300     | 0.240253     |
# | loss_h     | 0.320947     | 0.145222     | 0.172824     |
# | loss_obj   | 3.024681     | 3.058475     | 2.953052     |
# | loss_cls   | 0.057774     | 0.054208     | 0.054417     |
# | cls_acc    | 33.90%       | 34.85%       | 32.84%       |
# | conf_obj   | 0.205553     | 0.232007     | 0.241201     |
# | conf_noobj | 0.007140     | 0.007656     | 0.007524     |
# +------------+--------------+--------------+--------------+
# Total loss 11.292492866516113
# ---- ETA 0:27:25.671059
#  66% 867/1304 [07:00<03:03,  2.38it/s]
# ---- [Epoch 2/3, Batch 868/1304] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 11           | 22           | 44           |
# | loss       | 4.728656     | 3.910760     | 3.694638     |
# | loss_x     | 0.068569     | 0.073972     | 0.068458     |
# | loss_y     | 0.072701     | 0.063228     | 0.072240     |
# | loss_w     | 0.574130     | 0.266944     | 0.214259     |
# | loss_h     | 0.629959     | 0.362720     | 0.423667     |
# | loss_obj   | 3.325335     | 3.091587     | 2.866744     |
# | loss_cls   | 0.057963     | 0.052309     | 0.049270     |
# | cls_acc    | 33.33%       | 33.33%       | 34.00%       |
# | conf_obj   | 0.142723     | 0.199855     | 0.263979     |
# | conf_noobj | 0.007710     | 0.007710     | 0.007793     |
# +------------+--------------+--------------+--------------+
# Total loss 12.334053039550781
# ---- ETA 0:08:37.604992
# 100% 1301/1304 [10:23<00:01,  1.77it/s]
# ---- [Epoch 2/3, Batch 1302/1304] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 10           | 20           | 40           |
# | loss       | 4.533364     | 4.019886     | 3.431145     |
# | loss_x     | 0.092872     | 0.087604     | 0.092516     |
# | loss_y     | 0.058314     | 0.065516     | 0.076745     |
# | loss_w     | 0.203521     | 0.141212     | 0.203368     |
# | loss_h     | 0.247506     | 0.121536     | 0.200629     |
# | loss_obj   | 3.855037     | 3.527275     | 2.786046     |
# | loss_cls   | 0.076115     | 0.076744     | 0.071841     |
# | cls_acc    | 2.86%        | 2.70%        | 13.16%       |
# | conf_obj   | 0.123181     | 0.152827     | 0.273042     |
# | conf_noobj | 0.008091     | 0.007887     | 0.007645     |
# +------------+--------------+--------------+--------------+
# Total loss 11.984394073486328
# ---- ETA 0:00:01.894643
# 100% 1304/1304 [10:24<00:00,  2.09it/s]
# Current epoch loss : 12.26850 Saved at checkpoints/Yolo_V3_coco.pth
# 1304
#  33% 433/1304 [03:21<06:40,  2.18it/s]
# ---- [Epoch 3/3, Batch 434/1304] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 10           | 20           | 40           |
# | loss       | 4.582065     | 3.484142     | 3.174803     |
# | loss_x     | 0.085748     | 0.057232     | 0.057801     |
# | loss_y     | 0.062261     | 0.061896     | 0.067975     |
# | loss_w     | 1.026984     | 0.330314     | 0.205644     |
# | loss_h     | 0.404873     | 0.236213     | 0.116763     |
# | loss_obj   | 2.951918     | 2.754002     | 2.686469     |
# | loss_cls   | 0.050281     | 0.044485     | 0.040150     |
# | cls_acc    | 42.50%       | 48.98%       | 52.63%       |
# | conf_obj   | 0.190182     | 0.257468     | 0.296894     |
# | conf_noobj | 0.006309     | 0.007349     | 0.007534     |
# +------------+--------------+--------------+--------------+
# Total loss 11.241008758544922
# ---- ETA 0:47:58.213169
#  66% 867/1304 [06:48<04:36,  1.58it/s]
# ---- [Epoch 3/3, Batch 868/1304] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 15           | 30           | 60           |
# | loss       | 4.521909     | 3.836626     | 3.561530     |
# | loss_x     | 0.077846     | 0.078356     | 0.085967     |
# | loss_y     | 0.083546     | 0.066318     | 0.077628     |
# | loss_w     | 0.365872     | 0.225273     | 0.354459     |
# | loss_h     | 0.210105     | 0.187090     | 0.287821     |
# | loss_obj   | 3.732332     | 3.233296     | 2.713504     |
# | loss_cls   | 0.052207     | 0.046293     | 0.042152     |
# | cls_acc    | 38.30%       | 41.51%       | 42.11%       |
# | conf_obj   | 0.173406     | 0.233012     | 0.289033     |
# | conf_noobj | 0.009052     | 0.008247     | 0.007335     |
# +------------+--------------+--------------+--------------+
# Total loss 11.920064926147461
# ---- ETA 0:13:45.668709
# 100% 1301/1304 [10:17<00:01,  1.69it/s]
# ---- [Epoch 3/3, Batch 1302/1304] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 12           | 24           | 48           |
# | loss       | 4.456329     | 3.555816     | 3.538769     |
# | loss_x     | 0.092658     | 0.056802     | 0.069301     |
# | loss_y     | 0.117943     | 0.065350     | 0.088282     |
# | loss_w     | 0.374459     | 0.129754     | 0.235838     |
# | loss_h     | 0.138703     | 0.076111     | 0.309678     |
# | loss_obj   | 3.670725     | 3.167066     | 2.768092     |
# | loss_cls   | 0.061841     | 0.060734     | 0.067577     |
# | cls_acc    | 20.00%       | 20.00%       | 20.00%       |
# | conf_obj   | 0.172269     | 0.256671     | 0.297906     |
# | conf_noobj | 0.009824     | 0.008867     | 0.008319     |
# +------------+--------------+--------------+--------------+
# Total loss 11.55091381072998
# ---- ETA 0:00:02.845260
# 100% 1304/1304 [10:18<00:00,  2.11it/s]
# Current epoch loss : 12.29335 Saved at checkpoints/Yolo_V3_coco.pth
#
# ---- Evaluating Model ----
# Detecting objects: 100% 316/316 [00:58<00:00,  5.39it/s]
# Computing AP: 100% 80/80 [00:00<00:00, 747.01it/s]
# +-------+----------------+---------+
# | Index | Class name     | AP      |
# +-------+----------------+---------+
# | 0     | person         | 0.13126 |
# | 1     | bicycle        | 0.00000 |
# | 2     | car            | 0.06598 |
# | 3     | motorbike      | 0.00000 |
# | 4     | aeroplane      | 0.00000 |
# | 5     | bus            | 0.00000 |
# | 6     | train          | 0.00000 |
# | 7     | truck          | 0.00000 |
# | 8     | boat           | 0.00000 |
# | 9     | traffic light  | 0.00000 |
# | 10    | fire hydrant   | 0.00000 |
# | 11    | stop sign      | 0.00000 |
# | 12    | parking meter  | 0.00000 |
# | 13    | bench          | 0.00000 |
# | 14    | bird           | 0.00000 |
# | 15    | cat            | 0.00000 |
# | 16    | dog            | 0.00000 |
# | 17    | horse          | 0.00000 |
# | 18    | sheep          | 0.00000 |
# | 19    | cow            | 0.00000 |
# | 20    | elephant       | 0.00000 |
# | 21    | bear           | 0.00000 |
# | 22    | zebra          | 0.00000 |
# | 23    | giraffe        | 0.00000 |
# | 24    | backpack       | 0.00000 |
# | 25    | umbrella       | 0.00000 |
# | 26    | handbag        | 0.00000 |
# | 27    | tie            | 0.00000 |
# | 28    | suitcase       | 0.00000 |
# | 29    | frisbee        | 0.00000 |
# | 30    | skis           | 0.00000 |
# | 31    | snowboard      | 0.00000 |
# | 32    | sports ball    | 0.05492 |
# | 33    | kite           | 0.00000 |
# | 34    | baseball bat   | 0.00000 |
# | 35    | baseball glove | 0.00000 |
# | 36    | skateboard     | 0.00021 |
# | 37    | surfboard      | 0.00000 |
# | 38    | tennis racket  | 0.00000 |
# | 39    | bottle         | 0.00197 |
# | 40    | wine glass     | 0.00000 |
# | 41    | cup            | 0.00754 |
# | 42    | fork           | 0.00000 |
# | 43    | knife          | 0.00000 |
# | 44    | spoon          | 0.00000 |
# | 45    | bowl           | 0.00169 |
# | 46    | banana         | 0.00000 |
# | 47    | apple          | 0.00000 |
# | 48    | sandwich       | 0.00000 |
# | 49    | orange         | 0.00000 |
# | 50    | broccoli       | 0.00000 |
# | 51    | carrot         | 0.00000 |
# | 52    | hot dog        | 0.00000 |
# | 53    | pizza          | 0.00000 |
# | 54    | donut          | 0.00000 |
# | 55    | cake           | 0.00000 |
# | 56    | chair          | 0.00018 |
# | 57    | sofa           | 0.00000 |
# | 58    | pottedplant    | 0.00000 |
# | 59    | bed            | 0.00000 |
# | 60    | diningtable    | 0.00000 |
# | 61    | toilet         | 0.00000 |
# | 62    | tvmonitor      | 0.00000 |
# | 63    | laptop         | 0.00000 |
# | 64    | mouse          | 0.00000 |
# | 65    | remote         | 0.00000 |
# | 66    | keyboard       | 0.00000 |
# | 67    | cell phone     | 0.00000 |
# | 68    | microwave      | 0.00000 |
# | 69    | oven           | 0.00000 |
# | 70    | toaster        | 0.00000 |
# | 71    | sink           | 0.00000 |
# | 72    | refrigerator   | 0.00000 |
# | 73    | book           | 0.00000 |
# | 74    | clock          | 0.00000 |
# | 75    | vase           | 0.00000 |
# | 76    | scissors       | 0.00000 |
# | 77    | teddy bear     | 0.00000 |
# | 78    | hair drier     | 0.00000 |
# | 79    | toothbrush     | 0.00000 |
# +-------+----------------+---------+
# ---- mAP 0.00329701090002855

# %% [markdown]
# # 11. Train YOLO v3 from Darknet Weights

# %%
! python train.py --num_epochs 3 --batch_size 8 --data_config config/coco.data --model_def config/yolov3.cfg --pretrained_path checkpoints/yolov3.weights --save_path checkpoints/Yolo_V3_coco.pth
# Out:
# {'data_config': 'config/coco.data', 'model_def': 'config/yolov3.cfg', 'pretrained_path': 'checkpoints/yolov3.weights', 'save_path': 'checkpoints/Yolo_V3_coco.pth', 'working_dir': './', 'num_epochs': 3, 'batch_size': 8, 'img_size': 416, 'n_cpu': 1, 'gradient_accumulations': 2, 'evaluation_interval': 2, 'multiscale_training': True, 'checkpoint_freq': 2, 'iou_thres': 0.5, 'conf_thres': 0.5, 'nms_thres': 0.5, 'ckpt_dir': './checkpoints', 'logs_dir': './logs'}
# cuda
# checkpoints/yolov3.weights
# Darknet weight loaded!
# 1304
#  33% 433/1304 [03:17<05:46,  2.51it/s]
# ---- [Epoch 1/3, Batch 434/1304] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 12           | 24           | 48           |
# | loss       | 4.106850     | 3.685760     | 3.417358     |
# | loss_x     | 0.082772     | 0.072119     | 0.071559     |
# | loss_y     | 0.059223     | 0.050320     | 0.052036     |
# | loss_w     | 0.277510     | 0.105043     | 0.196390     |
# | loss_h     | 0.230462     | 0.161852     | 0.246952     |
# | loss_obj   | 3.399043     | 3.250401     | 2.808318     |
# | loss_cls   | 0.057840     | 0.046026     | 0.042103     |
# | cls_acc    | 27.59%       | 35.64%       | 42.72%       |
# | conf_obj   | 0.167600     | 0.189289     | 0.253643     |
# | conf_noobj | 0.007140     | 0.007954     | 0.007286     |
# +------------+--------------+--------------+--------------+
# Total loss 11.209968566894531
# ---- ETA 0:06:37.123137
#  66% 867/1304 [06:43<02:36,  2.79it/s]
# ---- [Epoch 1/3, Batch 868/1304] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 10           | 20           | 40           |
# | loss       | 3.874998     | 3.567433     | 3.436394     |
# | loss_x     | 0.085811     | 0.063965     | 0.045494     |
# | loss_y     | 0.069867     | 0.057267     | 0.081761     |
# | loss_w     | 0.623632     | 0.196927     | 0.230523     |
# | loss_h     | 0.225151     | 0.123927     | 0.196045     |
# | loss_obj   | 2.803161     | 3.066414     | 2.831710     |
# | loss_cls   | 0.067377     | 0.058934     | 0.050861     |
# | cls_acc    | 21.57%       | 28.57%       | 30.30%       |
# | conf_obj   | 0.243489     | 0.218397     | 0.229128     |
# | conf_noobj | 0.007060     | 0.008446     | 0.007590     |
# +------------+--------------+--------------+--------------+
# Total loss 10.878825187683105
# ---- ETA 0:03:22.650718
# 100% 1301/1304 [09:58<00:01,  2.97it/s]
# ---- [Epoch 1/3, Batch 1302/1304] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 10           | 20           | 40           |
# | loss       | 4.244118     | 3.920179     | 3.111051     |
# | loss_x     | 0.063574     | 0.063405     | 0.056245     |
# | loss_y     | 0.084269     | 0.070087     | 0.048773     |
# | loss_w     | 0.635068     | 0.366351     | 0.139877     |
# | loss_h     | 0.359095     | 0.271495     | 0.130394     |
# | loss_obj   | 3.041465     | 3.100499     | 2.696309     |
# | loss_cls   | 0.060647     | 0.048344     | 0.039453     |
# | cls_acc    | 39.22%       | 44.44%       | 53.73%       |
# | conf_obj   | 0.203007     | 0.222167     | 0.305432     |
# | conf_noobj | 0.006459     | 0.007705     | 0.007409     |
# +------------+--------------+--------------+--------------+
# Total loss 11.275348663330078
# ---- ETA 0:00:00.920111
# 100% 1304/1304 [09:59<00:00,  2.18it/s]
# Current epoch loss : 11.31679 Saved at checkpoints/Yolo_V3_coco.pth
# 1304
#  33% 433/1304 [03:43<09:43,  1.49it/s]
# ---- [Epoch 2/3, Batch 434/1304] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 15           | 30           | 60           |
# | loss       | 3.437306     | 3.016767     | 3.021019     |
# | loss_x     | 0.053043     | 0.060172     | 0.078778     |
# | loss_y     | 0.071498     | 0.053179     | 0.055478     |
# | loss_w     | 0.164676     | 0.079519     | 0.122725     |
# | loss_h     | 0.213010     | 0.074615     | 0.083782     |
# | loss_obj   | 2.890635     | 2.705570     | 2.633663     |
# | loss_cls   | 0.044444     | 0.043712     | 0.046592     |
# | cls_acc    | 53.57%       | 53.57%       | 53.57%       |
# | conf_obj   | 0.323687     | 0.340619     | 0.295573     |
# | conf_noobj | 0.008403     | 0.006498     | 0.006413     |
# +------------+--------------+--------------+--------------+
# Total loss 9.475090980529785
# ---- ETA 0:27:32.136240
#  66% 867/1304 [07:12<03:46,  1.93it/s]
# ---- [Epoch 2/3, Batch 868/1304] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 13           | 26           | 52           |
# | loss       | 4.298558     | 3.361617     | 3.003695     |
# | loss_x     | 0.065900     | 0.052891     | 0.073006     |
# | loss_y     | 0.055590     | 0.043780     | 0.073553     |
# | loss_w     | 0.261657     | 0.310824     | 0.272366     |
# | loss_h     | 0.178474     | 0.108251     | 0.151024     |
# | loss_obj   | 3.678500     | 2.790874     | 2.380849     |
# | loss_cls   | 0.058436     | 0.054997     | 0.052897     |
# | cls_acc    | 28.57%       | 30.30%       | 38.89%       |
# | conf_obj   | 0.223525     | 0.273762     | 0.384173     |
# | conf_noobj | 0.008138     | 0.006611     | 0.006595     |
# +------------+--------------+--------------+--------------+
# Total loss 10.663869857788086
# ---- ETA 0:08:38.714768
# 100% 1301/1304 [10:31<00:01,  2.45it/s]
# ---- [Epoch 2/3, Batch 1302/1304] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 10           | 20           | 40           |
# | loss       | 4.861154     | 3.679513     | 3.442467     |
# | loss_x     | 0.073524     | 0.060301     | 0.062351     |
# | loss_y     | 0.038802     | 0.094879     | 0.086697     |
# | loss_w     | 0.467731     | 0.171008     | 0.121836     |
# | loss_h     | 0.460353     | 0.265353     | 0.168683     |
# | loss_obj   | 3.765733     | 3.040029     | 2.956172     |
# | loss_cls   | 0.055011     | 0.047943     | 0.046729     |
# | cls_acc    | 24.07%       | 26.56%       | 31.94%       |
# | conf_obj   | 0.115292     | 0.211582     | 0.236209     |
# | conf_noobj | 0.006686     | 0.007831     | 0.007753     |
# +------------+--------------+--------------+--------------+
# Total loss 11.983135223388672
# ---- ETA 0:00:01.891838
# 100% 1304/1304 [10:32<00:00,  2.06it/s]
# Current epoch loss : 10.67925 Saved at checkpoints/Yolo_V3_coco.pth
# 1304
#  33% 433/1304 [03:38<06:42,  2.16it/s]
# ---- [Epoch 3/3, Batch 434/1304] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 10           | 20           | 40           |
# | loss       | 4.176210     | 3.981041     | 3.898962     |
# | loss_x     | 0.066806     | 0.057266     | 0.053047     |
# | loss_y     | 0.072844     | 0.058668     | 0.068465     |
# | loss_w     | 0.599982     | 0.272419     | 0.136557     |
# | loss_h     | 0.526816     | 0.207360     | 0.224588     |
# | loss_obj   | 2.856565     | 3.337573     | 3.369284     |
# | loss_cls   | 0.053198     | 0.047754     | 0.047021     |
# | cls_acc    | 38.98%       | 41.89%       | 44.30%       |
# | conf_obj   | 0.192253     | 0.196672     | 0.179987     |
# | conf_noobj | 0.006358     | 0.007959     | 0.007488     |
# +------------+--------------+--------------+--------------+
# Total loss 12.05621337890625
# ---- ETA 0:48:29.092681
#  66% 867/1304 [06:56<05:04,  1.44it/s]
# ---- [Epoch 3/3, Batch 868/1304] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 16           | 32           | 64           |
# | loss       | 3.961248     | 3.499688     | 3.204895     |
# | loss_x     | 0.097044     | 0.074598     | 0.057472     |
# | loss_y     | 0.068672     | 0.071557     | 0.061785     |
# | loss_w     | 0.518350     | 0.247655     | 0.166470     |
# | loss_h     | 0.518073     | 0.204241     | 0.187129     |
# | loss_obj   | 2.709423     | 2.860788     | 2.693810     |
# | loss_cls   | 0.049686     | 0.040848     | 0.038230     |
# | cls_acc    | 40.00%       | 40.70%       | 51.72%       |
# | conf_obj   | 0.308642     | 0.287379     | 0.318066     |
# | conf_noobj | 0.008583     | 0.007925     | 0.007738     |
# +------------+--------------+--------------+--------------+
# Total loss 10.665830612182617
# ---- ETA 0:13:48.472230
# 100% 1301/1304 [10:33<00:01,  2.94it/s]
# ---- [Epoch 3/3, Batch 1302/1304] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 10           | 20           | 40           |
# | loss       | 4.566618     | 4.225349     | 3.435483     |
# | loss_x     | 0.078992     | 0.066162     | 0.074442     |
# | loss_y     | 0.066743     | 0.068280     | 0.076606     |
# | loss_w     | 0.539220     | 0.209733     | 0.094584     |
# | loss_h     | 0.236060     | 0.199355     | 0.200757     |
# | loss_obj   | 3.583880     | 3.626353     | 2.935555     |
# | loss_cls   | 0.061724     | 0.055466     | 0.053538     |
# | cls_acc    | 8.11%        | 26.83%       | 26.19%       |
# | conf_obj   | 0.139435     | 0.176423     | 0.232379     |
# | conf_noobj | 0.007578     | 0.008145     | 0.007612     |
# +------------+--------------+--------------+--------------+
# Total loss 12.227450370788574
# ---- ETA 0:00:02.867361
# 100% 1304/1304 [10:34<00:00,  2.06it/s]
# Current epoch loss : 10.72268 Saved at checkpoints/Yolo_V3_coco.pth
#
# ---- Evaluating Model ----
# Detecting objects: 100% 316/316 [01:01<00:00,  5.13it/s]
# Computing AP: 100% 80/80 [00:00<00:00, 618.70it/s]
# +-------+----------------+---------+
# | Index | Class name     | AP      |
# +-------+----------------+---------+
# | 0     | person         | 0.20746 |
# | 1     | bicycle        | 0.00000 |
# | 2     | car            | 0.19586 |
# | 3     | motorbike      | 0.00000 |
# | 4     | aeroplane      | 0.00779 |
# | 5     | bus            | 0.00000 |
# | 6     | train          | 0.00000 |
# | 7     | truck          | 0.00000 |
# | 8     | boat           | 0.00008 |
# | 9     | traffic light  | 0.04315 |
# | 10    | fire hydrant   | 0.00000 |
# | 11    | stop sign      | 0.01471 |
# | 12    | parking meter  | 0.00000 |
# | 13    | bench          | 0.00000 |
# | 14    | bird           | 0.00000 |
# | 15    | cat            | 0.00000 |
# | 16    | dog            | 0.00000 |
# | 17    | horse          | 0.00000 |
# | 18    | sheep          | 0.00000 |
# | 19    | cow            | 0.00000 |
# | 20    | elephant       | 0.00000 |
# | 21    | bear           | 0.00000 |
# | 22    | zebra          | 0.01741 |
# | 23    | giraffe        | 0.00000 |
# | 24    | backpack       | 0.00238 |
# | 25    | umbrella       | 0.00578 |
# | 26    | handbag        | 0.00759 |
# | 27    | tie            | 0.01096 |
# | 28    | suitcase       | 0.00000 |
# | 29    | frisbee        | 0.01471 |
# | 30    | skis           | 0.00000 |
# | 31    | snowboard      | 0.01239 |
# | 32    | sports ball    | 0.01552 |
# | 33    | kite           | 0.05757 |
# | 34    | baseball bat   | 0.00000 |
# | 35    | baseball glove | 0.00000 |
# | 36    | skateboard     | 0.04299 |
# | 37    | surfboard      | 0.00000 |
# | 38    | tennis racket  | 0.00000 |
# | 39    | bottle         | 0.10764 |
# | 40    | wine glass     | 0.00000 |
# | 41    | cup            | 0.01646 |
# | 42    | fork           | 0.00000 |
# | 43    | knife          | 0.00000 |
# | 44    | spoon          | 0.00000 |
# | 45    | bowl           | 0.07358 |
# | 46    | banana         | 0.00000 |
# | 47    | apple          | 0.00000 |
# | 48    | sandwich       | 0.00000 |
# | 49    | orange         | 0.00000 |
# | 50    | broccoli       | 0.00000 |
# | 51    | carrot         | 0.00000 |
# | 52    | hot dog        | 0.00000 |
# | 53    | pizza          | 0.00049 |
# | 54    | donut          | 0.00215 |
# | 55    | cake           | 0.00000 |
# | 56    | chair          | 0.00564 |
# | 57    | sofa           | 0.00000 |
# | 58    | pottedplant    | 0.00897 |
# | 59    | bed            | 0.00000 |
# | 60    | diningtable    | 0.00417 |
# | 61    | toilet         | 0.00000 |
# | 62    | tvmonitor      | 0.01441 |
# | 63    | laptop         | 0.00735 |
# | 64    | mouse          | 0.00000 |
# | 65    | remote         | 0.00000 |
# | 66    | keyboard       | 0.01639 |
# | 67    | cell phone     | 0.00382 |
# | 68    | microwave      | 0.00000 |
# | 69    | oven           | 0.00000 |
# | 70    | toaster        | 0.00000 |
# | 71    | sink           | 0.00000 |
# | 72    | refrigerator   | 0.00000 |
# | 73    | book           | 0.00905 |
# | 74    | clock          | 0.14026 |
# | 75    | vase           | 0.00000 |
# | 76    | scissors       | 0.00000 |
# | 77    | teddy bear     | 0.00000 |
# | 78    | hair drier     | 0.00000 |
# | 79    | toothbrush     | 0.00000 |
# +-------+----------------+---------+
# ---- mAP 0.0133341390325592

# %% [markdown]
# # 12. Train YOLO v3-tiny from Pre-trained Weights

# %%
! python train.py --num_epochs 3 --batch_size 32 --data_config config/coco.data --model_def config/yolov3-tiny.cfg --pretrained_path checkpoints/Yolo_V3_coco_tiny.pth --save_path checkpoints/Yolo_V3_coco_tiny.pth
# Out:
# {'data_config': 'config/coco.data', 'model_def': 'config/yolov3-tiny.cfg', 'pretrained_path': 'checkpoints/Yolo_V3_coco_tiny.pth', 'save_path': 'checkpoints/Yolo_V3_coco_tiny.pth', 'working_dir': './', 'num_epochs': 3, 'batch_size': 32, 'img_size': 416, 'n_cpu': 1, 'gradient_accumulations': 2, 'evaluation_interval': 2, 'multiscale_training': True, 'checkpoint_freq': 2, 'iou_thres': 0.5, 'conf_thres': 0.5, 'nms_thres': 0.5, 'ckpt_dir': './checkpoints', 'logs_dir': './logs'}
# cuda
# checkpoints/Yolo_V3_coco_tiny.pth
# Trained pytorch weight loaded!
# 326
#  33% 107/326 [00:42<01:19,  2.74it/s]
# ---- [Epoch 1/3, Batch 108/326] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 11           | 22           |
# | loss       | 3.868716     | 3.694857     |
# | loss_x     | 0.066677     | 0.066421     |
# | loss_y     | 0.068643     | 0.065060     |
# | loss_w     | 0.391307     | 0.218651     |
# | loss_h     | 0.341339     | 0.149080     |
# | loss_obj   | 2.964167     | 3.168243     |
# | loss_cls   | 0.036583     | 0.027402     |
# | cls_acc    | 57.21%       | 64.03%       |
# | conf_obj   | 0.186775     | 0.195541     |
# | conf_noobj | 0.007376     | 0.007866     |
# +------------+--------------+--------------+
# Total loss 7.563573837280273
# ---- ETA 0:01:26.375162
#  66% 215/326 [01:24<00:42,  2.61it/s]
# ---- [Epoch 1/3, Batch 216/326] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 13           | 26           |
# | loss       | 3.881224     | 3.425959     |
# | loss_x     | 0.065647     | 0.064926     |
# | loss_y     | 0.053634     | 0.061436     |
# | loss_w     | 0.407926     | 0.163455     |
# | loss_h     | 0.378984     | 0.150748     |
# | loss_obj   | 2.938696     | 2.957737     |
# | loss_cls   | 0.036337     | 0.027657     |
# | cls_acc    | 53.69%       | 59.93%       |
# | conf_obj   | 0.251033     | 0.270964     |
# | conf_noobj | 0.007958     | 0.008241     |
# +------------+--------------+--------------+
# Total loss 7.307182788848877
# ---- ETA 0:00:43.075214
#  99% 323/326 [02:05<00:01,  2.47it/s]
# ---- [Epoch 1/3, Batch 324/326] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 14           | 28           |
# | loss       | 3.605520     | 3.231857     |
# | loss_x     | 0.074133     | 0.061162     |
# | loss_y     | 0.065126     | 0.068356     |
# | loss_w     | 0.382480     | 0.200463     |
# | loss_h     | 0.176184     | 0.150397     |
# | loss_obj   | 2.870361     | 2.719961     |
# | loss_cls   | 0.037236     | 0.031517     |
# | cls_acc    | 48.67%       | 54.60%       |
# | conf_obj   | 0.269576     | 0.283280     |
# | conf_noobj | 0.007408     | 0.006974     |
# +------------+--------------+--------------+
# Total loss 6.837376594543457
# ---- ETA 0:00:00.780661
# 100% 326/326 [02:07<00:00,  2.56it/s]
# Current epoch loss : 7.47146 Saved at checkpoints/Yolo_V3_coco_tiny.pth
# 326
#  33% 107/326 [00:41<01:28,  2.49it/s]
# ---- [Epoch 2/3, Batch 108/326] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 16           | 32           |
# | loss       | 3.093247     | 2.855780     |
# | loss_x     | 0.069680     | 0.065607     |
# | loss_y     | 0.060118     | 0.062776     |
# | loss_w     | 0.222777     | 0.164337     |
# | loss_h     | 0.203234     | 0.130862     |
# | loss_obj   | 2.507728     | 2.407436     |
# | loss_cls   | 0.029709     | 0.024763     |
# | cls_acc    | 63.35%       | 67.14%       |
# | conf_obj   | 0.318845     | 0.329994     |
# | conf_noobj | 0.006499     | 0.006061     |
# +------------+--------------+--------------+
# Total loss 5.949027061462402
# ---- ETA 0:05:42.109646
#  66% 215/326 [01:24<00:43,  2.57it/s]
# ---- [Epoch 2/3, Batch 216/326] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 13           | 26           |
# | loss       | 3.350949     | 3.183871     |
# | loss_x     | 0.061440     | 0.066142     |
# | loss_y     | 0.059767     | 0.056903     |
# | loss_w     | 0.377788     | 0.225731     |
# | loss_h     | 0.327169     | 0.170539     |
# | loss_obj   | 2.489733     | 2.635658     |
# | loss_cls   | 0.035053     | 0.028898     |
# | cls_acc    | 58.79%       | 61.72%       |
# | conf_obj   | 0.307142     | 0.287082     |
# | conf_noobj | 0.006695     | 0.006830     |
# +------------+--------------+--------------+
# Total loss 6.534820079803467
# ---- ETA 0:01:48.147304
#  99% 323/326 [02:07<00:01,  2.51it/s]
# ---- [Epoch 2/3, Batch 324/326] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 13           | 26           |
# | loss       | 3.632303     | 3.424392     |
# | loss_x     | 0.066936     | 0.068254     |
# | loss_y     | 0.062219     | 0.069468     |
# | loss_w     | 0.289321     | 0.184759     |
# | loss_h     | 0.228143     | 0.125762     |
# | loss_obj   | 2.953430     | 2.949402     |
# | loss_cls   | 0.032253     | 0.026747     |
# | cls_acc    | 54.42%       | 63.05%       |
# | conf_obj   | 0.251412     | 0.252194     |
# | conf_noobj | 0.008106     | 0.007853     |
# +------------+--------------+--------------+
# Total loss 7.056694984436035
# ---- ETA 0:00:01.572646
# 100% 326/326 [02:08<00:00,  2.54it/s]
# Current epoch loss : 6.91404 Saved at checkpoints/Yolo_V3_coco_tiny.pth
# 326
#  33% 107/326 [00:42<01:33,  2.35it/s]
# ---- [Epoch 3/3, Batch 108/326] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 14           | 28           |
# | loss       | 3.412057     | 3.051609     |
# | loss_x     | 0.067264     | 0.057052     |
# | loss_y     | 0.061343     | 0.055077     |
# | loss_w     | 0.309897     | 0.143983     |
# | loss_h     | 0.221425     | 0.138819     |
# | loss_obj   | 2.723411     | 2.632924     |
# | loss_cls   | 0.028717     | 0.023755     |
# | cls_acc    | 65.46%       | 68.52%       |
# | conf_obj   | 0.294885     | 0.327948     |
# | conf_noobj | 0.007575     | 0.007266     |
# +------------+--------------+--------------+
# Total loss 6.463665962219238
# ---- ETA 0:10:03.178211
#  66% 215/326 [01:25<00:45,  2.45it/s]
# ---- [Epoch 3/3, Batch 216/326] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 13           | 26           |
# | loss       | 3.682060     | 3.353246     |
# | loss_x     | 0.080130     | 0.065880     |
# | loss_y     | 0.059092     | 0.064157     |
# | loss_w     | 0.381570     | 0.288277     |
# | loss_h     | 0.294343     | 0.231883     |
# | loss_obj   | 2.830195     | 2.670794     |
# | loss_cls   | 0.036730     | 0.032256     |
# | cls_acc    | 53.55%       | 60.39%       |
# | conf_obj   | 0.267811     | 0.301047     |
# | conf_noobj | 0.006998     | 0.006944     |
# +------------+--------------+--------------+
# Total loss 7.035305976867676
# ---- ETA 0:02:54.146033
#  99% 323/326 [02:09<00:01,  2.71it/s]
# ---- [Epoch 3/3, Batch 324/326] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 10           | 20           |
# | loss       | 3.678611     | 3.370833     |
# | loss_x     | 0.073767     | 0.067095     |
# | loss_y     | 0.046665     | 0.061552     |
# | loss_w     | 0.366598     | 0.189141     |
# | loss_h     | 0.261447     | 0.176841     |
# | loss_obj   | 2.895371     | 2.847678     |
# | loss_cls   | 0.034762     | 0.028527     |
# | cls_acc    | 59.24%       | 62.80%       |
# | conf_obj   | 0.253061     | 0.274737     |
# | conf_noobj | 0.007175     | 0.007657     |
# +------------+--------------+--------------+
# Total loss 7.049444198608398
# ---- ETA 0:00:02.377882
# 100% 326/326 [02:10<00:00,  2.50it/s]
# Current epoch loss : 6.83993 Saved at checkpoints/Yolo_V3_coco_tiny.pth
#
# ---- Evaluating Model ----
# Detecting objects: 100% 79/79 [00:30<00:00,  2.58it/s]
# Computing AP: 100% 80/80 [00:00<00:00, 794.12it/s]
# +-------+----------------+---------+
# | Index | Class name     | AP      |
# +-------+----------------+---------+
# | 0     | person         | 0.16379 |
# | 1     | bicycle        | 0.10430 |
# | 2     | car            | 0.09673 |
# | 3     | motorbike      | 0.07192 |
# | 4     | aeroplane      | 0.06383 |
# | 5     | bus            | 0.18618 |
# | 6     | train          | 0.09259 |
# | 7     | truck          | 0.01505 |
# | 8     | boat           | 0.00119 |
# | 9     | traffic light  | 0.06944 |
# | 10    | fire hydrant   | 0.07895 |
# | 11    | stop sign      | 0.31154 |
# | 12    | parking meter  | 0.01667 |
# | 13    | bench          | 0.00000 |
# | 14    | bird           | 0.00437 |
# | 15    | cat            | 0.09018 |
# | 16    | dog            | 0.05071 |
# | 17    | horse          | 0.11899 |
# | 18    | sheep          | 0.09078 |
# | 19    | cow            | 0.03444 |
# | 20    | elephant       | 0.21226 |
# | 21    | bear           | 0.01282 |
# | 22    | zebra          | 0.29345 |
# | 23    | giraffe        | 0.24463 |
# | 24    | backpack       | 0.00000 |
# | 25    | umbrella       | 0.09294 |
# | 26    | handbag        | 0.00162 |
# | 27    | tie            | 0.04890 |
# | 28    | suitcase       | 0.02177 |
# | 29    | frisbee        | 0.10155 |
# | 30    | skis           | 0.05504 |
# | 31    | snowboard      | 0.02830 |
# | 32    | sports ball    | 0.08176 |
# | 33    | kite           | 0.08349 |
# | 34    | baseball bat   | 0.03136 |
# | 35    | baseball glove | 0.12321 |
# | 36    | skateboard     | 0.06822 |
# | 37    | surfboard      | 0.06458 |
# | 38    | tennis racket  | 0.17387 |
# | 39    | bottle         | 0.01800 |
# | 40    | wine glass     | 0.03425 |
# | 41    | cup            | 0.10731 |
# | 42    | fork           | 0.02513 |
# | 43    | knife          | 0.00190 |
# | 44    | spoon          | 0.00781 |
# | 45    | bowl           | 0.08439 |
# | 46    | banana         | 0.00631 |
# | 47    | apple          | 0.12429 |
# | 48    | sandwich       | 0.04629 |
# | 49    | orange         | 0.06688 |
# | 50    | broccoli       | 0.06130 |
# | 51    | carrot         | 0.01908 |
# | 52    | hot dog        | 0.01370 |
# | 53    | pizza          | 0.17774 |
# | 54    | donut          | 0.13625 |
# | 55    | cake           | 0.03680 |
# | 56    | chair          | 0.03039 |
# | 57    | sofa           | 0.03812 |
# | 58    | pottedplant    | 0.00977 |
# | 59    | bed            | 0.03213 |
# | 60    | diningtable    | 0.00382 |
# | 61    | toilet         | 0.27925 |
# | 62    | tvmonitor      | 0.31934 |
# | 63    | laptop         | 0.20834 |
# | 64    | mouse          | 0.03538 |
# | 65    | remote         | 0.02001 |
# | 66    | keyboard       | 0.13515 |
# | 67    | cell phone     | 0.00513 |
# | 68    | microwave      | 0.12222 |
# | 69    | oven           | 0.02029 |
# | 70    | toaster        | 0.00000 |
# | 71    | sink           | 0.10293 |
# | 72    | refrigerator   | 0.02339 |
# | 73    | book           | 0.01880 |
# | 74    | clock          | 0.27094 |
# | 75    | vase           | 0.03614 |
# | 76    | scissors       | 0.00000 |
# | 77    | teddy bear     | 0.02771 |
# | 78    | hair drier     | 0.00000 |
# | 79    | toothbrush     | 0.00000 |
# +-------+----------------+---------+
# ---- mAP 0.07635110312783037

# %% [markdown]
# # 13. Train YOLO v3-tiny from Darknet Weights

# %%
! python train.py --num_epochs 3 --batch_size 32 --data_config config/coco.data --model_def config/yolov3-tiny.cfg --pretrained_path checkpoints/yolov3-tiny.weights --save_path checkpoints/Yolo_V3_coco_tiny.pth
# Out:
# {'data_config': 'config/coco.data', 'model_def': 'config/yolov3-tiny.cfg', 'pretrained_path': 'checkpoints/yolov3-tiny.weights', 'save_path': 'checkpoints/Yolo_V3_coco_tiny.pth', 'working_dir': './', 'num_epochs': 3, 'batch_size': 32, 'img_size': 416, 'n_cpu': 1, 'gradient_accumulations': 2, 'evaluation_interval': 2, 'multiscale_training': True, 'checkpoint_freq': 2, 'iou_thres': 0.5, 'conf_thres': 0.5, 'nms_thres': 0.5, 'ckpt_dir': './checkpoints', 'logs_dir': './logs'}
# cuda
# checkpoints/yolov3-tiny.weights
# Darknet weight loaded!
# 326
#  33% 107/326 [00:45<01:31,  2.38it/s]
# ---- [Epoch 1/3, Batch 108/326] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 14           | 28           |
# | loss       | 3.612052     | 3.537544     |
# | loss_x     | 0.072564     | 0.065150     |
# | loss_y     | 0.055572     | 0.060037     |
# | loss_w     | 0.349181     | 0.243509     |
# | loss_h     | 0.242790     | 0.171823     |
# | loss_obj   | 2.861752     | 2.970547     |
# | loss_cls   | 0.030193     | 0.026478     |
# | cls_acc    | 54.02%       | 58.42%       |
# | conf_obj   | 0.242595     | 0.249742     |
# | conf_noobj | 0.007356     | 0.006557     |
# +------------+--------------+--------------+
# Total loss 7.149596214294434
# ---- ETA 0:01:33.282068
#  66% 215/326 [01:30<00:47,  2.33it/s]
# ---- [Epoch 1/3, Batch 216/326] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 16           | 32           |
# | loss       | 3.412126     | 3.131768     |
# | loss_x     | 0.071845     | 0.075510     |
# | loss_y     | 0.057643     | 0.062201     |
# | loss_w     | 0.260486     | 0.184062     |
# | loss_h     | 0.277709     | 0.176907     |
# | loss_obj   | 2.722888     | 2.613447     |
# | loss_cls   | 0.021556     | 0.019641     |
# | cls_acc    | 71.72%       | 71.15%       |
# | conf_obj   | 0.286296     | 0.320063     |
# | conf_noobj | 0.007718     | 0.007366     |
# +------------+--------------+--------------+
# Total loss 6.543893814086914
# ---- ETA 0:00:46.296815
#  99% 323/326 [02:16<00:01,  2.32it/s]
# ---- [Epoch 1/3, Batch 324/326] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 16           | 32           |
# | loss       | 3.433401     | 3.229113     |
# | loss_x     | 0.067292     | 0.070876     |
# | loss_y     | 0.057970     | 0.050105     |
# | loss_w     | 0.356273     | 0.262199     |
# | loss_h     | 0.160166     | 0.141752     |
# | loss_obj   | 2.760977     | 2.675164     |
# | loss_cls   | 0.030723     | 0.029018     |
# | cls_acc    | 58.60%       | 53.96%       |
# | conf_obj   | 0.245147     | 0.310666     |
# | conf_noobj | 0.007056     | 0.006469     |
# +------------+--------------+--------------+
# Total loss 6.662513732910156
# ---- ETA 0:00:00.848566
# 100% 326/326 [02:18<00:00,  2.36it/s]
# Current epoch loss : 7.52422 Saved at checkpoints/Yolo_V3_coco_tiny.pth
# 326
#  33% 107/326 [00:43<01:22,  2.67it/s]
# ---- [Epoch 2/3, Batch 108/326] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 10           | 20           |
# | loss       | 3.675425     | 3.358091     |
# | loss_x     | 0.070159     | 0.060169     |
# | loss_y     | 0.067017     | 0.066013     |
# | loss_w     | 0.306355     | 0.194487     |
# | loss_h     | 0.342099     | 0.163000     |
# | loss_obj   | 2.858951     | 2.850031     |
# | loss_cls   | 0.030843     | 0.024391     |
# | cls_acc    | 57.22%       | 62.96%       |
# | conf_obj   | 0.244152     | 0.253774     |
# | conf_noobj | 0.007603     | 0.007375     |
# +------------+--------------+--------------+
# Total loss 7.0335164070129395
# ---- ETA 0:06:08.478320
#  66% 215/326 [01:26<00:43,  2.53it/s]
# ---- [Epoch 2/3, Batch 216/326] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 13           | 26           |
# | loss       | 2.947320     | 2.615864     |
# | loss_x     | 0.057728     | 0.062590     |
# | loss_y     | 0.060940     | 0.062541     |
# | loss_w     | 0.210873     | 0.132056     |
# | loss_h     | 0.192411     | 0.124982     |
# | loss_obj   | 2.396569     | 2.205836     |
# | loss_cls   | 0.028798     | 0.027859     |
# | cls_acc    | 56.64%       | 57.96%       |
# | conf_obj   | 0.326939     | 0.382014     |
# | conf_noobj | 0.006422     | 0.006169     |
# +------------+--------------+--------------+
# Total loss 5.563183784484863
# ---- ETA 0:01:54.925792
#  99% 323/326 [02:10<00:01,  2.43it/s]
# ---- [Epoch 2/3, Batch 324/326] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 11           | 22           |
# | loss       | 3.563146     | 3.232539     |
# | loss_x     | 0.064964     | 0.067961     |
# | loss_y     | 0.043918     | 0.063943     |
# | loss_w     | 0.257194     | 0.163020     |
# | loss_h     | 0.212061     | 0.152133     |
# | loss_obj   | 2.954130     | 2.760515     |
# | loss_cls   | 0.030879     | 0.024968     |
# | cls_acc    | 60.33%       | 65.92%       |
# | conf_obj   | 0.243648     | 0.250542     |
# | conf_noobj | 0.007281     | 0.006906     |
# +------------+--------------+--------------+
# Total loss 6.795684814453125
# ---- ETA 0:00:01.660798
# 100% 326/326 [02:11<00:00,  2.48it/s]
# Current epoch loss : 6.82660 Saved at checkpoints/Yolo_V3_coco_tiny.pth
# 326
#  33% 107/326 [00:42<01:37,  2.25it/s]
# ---- [Epoch 3/3, Batch 108/326] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 15           | 30           |
# | loss       | 3.513385     | 3.198023     |
# | loss_x     | 0.062569     | 0.066326     |
# | loss_y     | 0.051513     | 0.062891     |
# | loss_w     | 0.289638     | 0.209441     |
# | loss_h     | 0.253521     | 0.170266     |
# | loss_obj   | 2.823531     | 2.659694     |
# | loss_cls   | 0.032611     | 0.029404     |
# | cls_acc    | 53.37%       | 57.62%       |
# | conf_obj   | 0.260800     | 0.290289     |
# | conf_noobj | 0.006982     | 0.006364     |
# +------------+--------------+--------------+
# Total loss 6.711407661437988
# ---- ETA 0:10:32.079427
#  66% 215/326 [01:25<00:43,  2.55it/s]
# ---- [Epoch 3/3, Batch 216/326] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 12           | 24           |
# | loss       | 3.636941     | 3.349891     |
# | loss_x     | 0.065313     | 0.072676     |
# | loss_y     | 0.061214     | 0.059635     |
# | loss_w     | 0.296095     | 0.168232     |
# | loss_h     | 0.373709     | 0.169373     |
# | loss_obj   | 2.813252     | 2.858514     |
# | loss_cls   | 0.027358     | 0.021461     |
# | cls_acc    | 63.28%       | 70.14%       |
# | conf_obj   | 0.283676     | 0.263398     |
# | conf_noobj | 0.007294     | 0.006833     |
# +------------+--------------+--------------+
# Total loss 6.9868316650390625
# ---- ETA 0:03:01.256654
#  99% 323/326 [02:08<00:01,  2.36it/s]
# ---- [Epoch 3/3, Batch 324/326] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 14           | 28           |
# | loss       | 3.360920     | 3.038684     |
# | loss_x     | 0.060763     | 0.062297     |
# | loss_y     | 0.057241     | 0.055574     |
# | loss_w     | 0.198874     | 0.130592     |
# | loss_h     | 0.233817     | 0.153304     |
# | loss_obj   | 2.778721     | 2.611001     |
# | loss_cls   | 0.031502     | 0.025917     |
# | cls_acc    | 61.17%       | 66.17%       |
# | conf_obj   | 0.255099     | 0.296353     |
# | conf_noobj | 0.007022     | 0.006740     |
# +------------+--------------+--------------+
# Total loss 6.399603843688965
# ---- ETA 0:00:02.463326
# 100% 326/326 [02:09<00:00,  2.51it/s]
# Current epoch loss : 6.86296 Saved at checkpoints/Yolo_V3_coco_tiny.pth
#
# ---- Evaluating Model ----
# Detecting objects: 100% 79/79 [00:30<00:00,  2.61it/s]
# Computing AP: 100% 80/80 [00:00<00:00, 652.24it/s]
# +-------+----------------+---------+
# | Index | Class name     | AP      |
# +-------+----------------+---------+
# | 0     | person         | 0.18158 |
# | 1     | bicycle        | 0.09286 |
# | 2     | car            | 0.09968 |
# | 3     | motorbike      | 0.12229 |
# | 4     | aeroplane      | 0.06392 |
# | 5     | bus            | 0.19309 |
# | 6     | train          | 0.10729 |
# | 7     | truck          | 0.05595 |
# | 8     | boat           | 0.01025 |
# | 9     | traffic light  | 0.08385 |
# | 10    | fire hydrant   | 0.16535 |
# | 11    | stop sign      | 0.30884 |
# | 12    | parking meter  | 0.03333 |
# | 13    | bench          | 0.01896 |
# | 14    | bird           | 0.01058 |
# | 15    | cat            | 0.09880 |
# | 16    | dog            | 0.06269 |
# | 17    | horse          | 0.11215 |
# | 18    | sheep          | 0.14211 |
# | 19    | cow            | 0.05946 |
# | 20    | elephant       | 0.25639 |
# | 21    | bear           | 0.22692 |
# | 22    | zebra          | 0.23560 |
# | 23    | giraffe        | 0.32424 |
# | 24    | backpack       | 0.01694 |
# | 25    | umbrella       | 0.06781 |
# | 26    | handbag        | 0.00009 |
# | 27    | tie            | 0.06689 |
# | 28    | suitcase       | 0.04379 |
# | 29    | frisbee        | 0.18745 |
# | 30    | skis           | 0.06996 |
# | 31    | snowboard      | 0.02830 |
# | 32    | sports ball    | 0.07873 |
# | 33    | kite           | 0.10767 |
# | 34    | baseball bat   | 0.03527 |
# | 35    | baseball glove | 0.09899 |
# | 36    | skateboard     | 0.13346 |
# | 37    | surfboard      | 0.08260 |
# | 38    | tennis racket  | 0.08318 |
# | 39    | bottle         | 0.03851 |
# | 40    | wine glass     | 0.04585 |
# | 41    | cup            | 0.12133 |
# | 42    | fork           | 0.05347 |
# | 43    | knife          | 0.03690 |
# | 44    | spoon          | 0.01172 |
# | 45    | bowl           | 0.12311 |
# | 46    | banana         | 0.03250 |
# | 47    | apple          | 0.07896 |
# | 48    | sandwich       | 0.02456 |
# | 49    | orange         | 0.08471 |
# | 50    | broccoli       | 0.07346 |
# | 51    | carrot         | 0.03649 |
# | 52    | hot dog        | 0.04338 |
# | 53    | pizza          | 0.11091 |
# | 54    | donut          | 0.16600 |
# | 55    | cake           | 0.10313 |
# | 56    | chair          | 0.04565 |
# | 57    | sofa           | 0.01376 |
# | 58    | pottedplant    | 0.01386 |
# | 59    | bed            | 0.01606 |
# | 60    | diningtable    | 0.01414 |
# | 61    | toilet         | 0.26400 |
# | 62    | tvmonitor      | 0.39032 |
# | 63    | laptop         | 0.20519 |
# | 64    | mouse          | 0.08054 |
# | 65    | remote         | 0.01056 |
# | 66    | keyboard       | 0.13941 |
# | 67    | cell phone     | 0.01779 |
# | 68    | microwave      | 0.08403 |
# | 69    | oven           | 0.04101 |
# | 70    | toaster        | 0.00000 |
# | 71    | sink           | 0.15801 |
# | 72    | refrigerator   | 0.06140 |
# | 73    | book           | 0.01697 |
# | 74    | clock          | 0.31011 |
# | 75    | vase           | 0.06658 |
# | 76    | scissors       | 0.04167 |
# | 77    | teddy bear     | 0.01000 |
# | 78    | hair drier     | 0.00000 |
# | 79    | toothbrush     | 0.00000 |
# +-------+----------------+---------+
# ---- mAP 0.09191687126279174
