# %% [markdown]
# # 1. [Opt] Check GPU Type

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
    print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
    print('and then re-execute this cell.')
else:
    print(gpu_info)
# Out:
# Thu Dec  8 21:48:26 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   47C    P0    28W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # 2. Git Clone from Github Repository to root directory
# At Colab, location is "/content/".
#
# Using `$ git clone https://github.com/lainyzine/git-clone.git` will load the Github repository with the name of the repository. With Colab, it can be convenient to work in the root directory. You can use the command to call the root directory as shown below.
#
# According to the Github repository, we can use `! git pull origin main` or `! Just use git pull origin master`.

# %%
# Clone from Github Repository
! git init .
! git remote add origin https://github.com/RichardMinsooGo-ML/Bible_3_21_Pytorch_YOLO_v3_Image.git
# ! git pull origin master
! git pull origin main
# Out:
# Initialized empty Git repository in /content/.git/
# remote: Enumerating objects: 1948, done.
# remote: Counting objects: 100% (89/89), done.
# remote: Compressing objects: 100% (86/86), done.
# remote: Total 1948 (delta 49), reused 2 (delta 2), pack-reused 1859
# Receiving objects: 100% (1948/1948), 58.68 MiB | 53.37 MiB/s, done.
# Resolving deltas: 100% (806/806), done.
# From https://github.com/RichardMinsooGo-ML/Bible_3_21_Pytorch_YOLO_v3_Image
#  * branch            main       -> FETCH_HEAD
#  * [new branch]      main       -> origin/main

# %% [markdown]
# # 3. import clear_output

# %%
from IPython.display import clear_output 
clear_output()

# %% [markdown]
# # 4. COCO dataset download from Auther's Github repository

# %%
# !pip install --upgrade --no-cache-dir gdown

import gdown
google_path = 'https://drive.google.com/uc?id='
file_id = '1AJfFAac6qBRpqqSbrQnJUh-y_7mzV9VV'
output_name = 'COCO.zip'
gdown.download(google_path+file_id,output_name,quiet=False)
# https://drive.google.com/file/d/1AJfFAac6qBRpqqSbrQnJUh-y_7mzV9VV/view?usp=sharing
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gdown in /usr/local/lib/python3.8/dist-packages (4.4.0)
# Collecting gdown
#   Downloading gdown-4.6.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from gdown) (4.64.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.8/dist-packages (from gdown) (4.6.3)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.8/dist-packages (from gdown) (2.23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from gdown) (3.8.0)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from gdown) (1.15.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->gdown) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->gdown) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->gdown) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->gdown) (2.10)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->gdown) (1.7.1)
# Installing collected packages: gdown
#   Attempting uninstall: gdown
#     Found existing installation: gdown 4.4.0
#     Uninstalling gdown-4.4.0:
#       Successfully uninstalled gdown-4.4.0
# Successfully installed gdown-4.6.0
# Downloading...
# From: https://drive.google.com/uc?id=1AJfFAac6qBRpqqSbrQnJUh-y_7mzV9VV
# To: /content/COCO.zip
# 100%|██████████| 20.0G/20.0G [03:33<00:00, 93.6MB/s]
# 'COCO.zip'

# %%
# !unzip /content/COCO.zip -d /content/dataset/COCO2017
clear_output()
! rm /content/COCO.zip

# %% [markdown]
# # 5. [Opt] Check Memory Space

# %%
# Memory Space
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
    print('To enable a high-RAM runtime, select the Runtime > "Change runtime type"')
    print('menu, and then select High-RAM in the Runtime shape dropdown. Then, ')
    print('re-execute this cell.')
else:
    print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 27.3 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %% [markdown]
# # 6. install terminaltables for Ascii Table print

# %%
# !pip install terminaltables
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting terminaltables
#   Downloading terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Installing collected packages: terminaltables
# Successfully installed terminaltables-3.1.10

# %% [markdown]
# # 7. Download Darknet Weights

# %%
# Download Darknet Weights
# ! wget https://pjreddie.com/media/files/yolo-voc.weights 
! wget https://pjreddie.com/media/files/yolov3-tiny.weights 
! wget https://pjreddie.com/media/files/yolov3.weights
# ! wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v3_optimal/yolov4.weights 
# ! wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v4_pre/yolov4-tiny.weights

import shutil
shutil.move("/content/yolov3-tiny.weights", "/content/checkpoints")
shutil.move("/content/yolov3.weights", "/content/checkpoints")
# shutil.move("/content/yolov4-tiny.weights", "/content/tmp")
# shutil.move("/content/yolov4.weights", "/content/tmp") 
shutil.rmtree("sample_data")
# Out:
# --2022-12-08 21:56:01--  https://pjreddie.com/media/files/yolov3-tiny.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35434956 (34M) [application/octet-stream]
# Saving to: ‘yolov3-tiny.weights’
#
# yolov3-tiny.weights 100%[===================>]  33.79M  27.1MB/s    in 1.2s
#
# 2022-12-08 21:56:03 (27.1 MB/s) - ‘yolov3-tiny.weights’ saved [35434956/35434956]
#
# --2022-12-08 21:56:03--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  40.2MB/s    in 6.2s
#
# 2022-12-08 21:56:09 (37.9 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %% [markdown]
# # 8. YOLO v3 Pre-Trained Weight gdown from Auther's GDrive

# %%
google_path = 'https://drive.google.com/uc?id='
file_id = '1NpwqosGph1uJrb2YbJ_EzR5R917tSZhb'
output_name = 'Yolo_V3_coco.pth'
gdown.download(google_path+file_id,output_name,quiet=False)
# https://drive.google.com/file/d/1NpwqosGph1uJrb2YbJ_EzR5R917tSZhb/view?usp=sharing

shutil.move("/content/Yolo_V3_coco.pth", "./checkpoints")
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1NpwqosGph1uJrb2YbJ_EzR5R917tSZhb
# To: /content/Yolo_V3_coco.pth
# 100%|██████████| 248M/248M [00:02<00:00, 86.5MB/s]
# './checkpoints/Yolo_V3_coco.pth'

# %% [markdown]
# # 9. YOLO v3-tiny Pre-Trained Weight gdown from Auther's GDrive

# %%
google_path = 'https://drive.google.com/uc?id='
file_id = '1DIxPr1V3c12U-0n9d4ZJulOdiHq7EaN5'
output_name = 'Yolo_V3_coco_tiny.pth'
gdown.download(google_path+file_id,output_name,quiet=False)
# https://drive.google.com/file/d/1DIxPr1V3c12U-0n9d4ZJulOdiHq7EaN5/view?usp=sharing

shutil.move("/content/Yolo_V3_coco_tiny.pth", "./checkpoints")
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1DIxPr1V3c12U-0n9d4ZJulOdiHq7EaN5
# To: /content/Yolo_V3_coco_tiny.pth
# 100%|██████████| 35.5M/35.5M [00:00<00:00, 52.4MB/s]
# './checkpoints/Yolo_V3_coco_tiny.pth'

# %%
# from google.colab import drive 
# drive.mount('/content/gdrive/')

# %% [markdown]
# # 10. Train YOLO v3 from Pre-trained Weights

# %%
! python train.py --num_epochs 3 --batch_size 8 --data_config config/coco.data --model_def config/yolov3.cfg --pretrained_path checkpoints/Yolo_V3_coco.pth --save_path checkpoints/Yolo_V3_coco.pth
# Out:
# {'data_config': 'config/coco.data', 'model_def': 'config/yolov3.cfg', 'pretrained_path': 'checkpoints/Yolo_V3_coco.pth', 'save_path': 'checkpoints/Yolo_V3_coco.pth', 'working_dir': './', 'num_epochs': 3, 'batch_size': 8, 'img_size': 416, 'n_cpu': 1, 'gradient_accumulations': 2, 'evaluation_interval': 2, 'multiscale_training': True, 'checkpoint_freq': 2, 'iou_thres': 0.5, 'conf_thres': 0.5, 'nms_thres': 0.5, 'ckpt_dir': './checkpoints', 'logs_dir': './logs'}
# cuda
# checkpoints/Yolo_V3_coco.pth
# Trained pytorch weight loaded!
# 14659
#  33% 4885/14659 [40:25<56:34,  2.88it/s]
# ---- [Epoch 1/3, Batch 4886/14659] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 10           | 20           | 40           |
# | loss       | 4.673634     | 3.880130     | 3.551001     |
# | loss_x     | 0.067231     | 0.089761     | 0.095200     |
# | loss_y     | 0.074084     | 0.070685     | 0.064491     |
# | loss_w     | 0.651135     | 0.276864     | 0.118217     |
# | loss_h     | 0.467712     | 0.209625     | 0.226276     |
# | loss_obj   | 3.345096     | 3.174070     | 2.990549     |
# | loss_cls   | 0.068377     | 0.059125     | 0.056268     |
# | cls_acc    | 14.71%       | 12.82%       | 16.67%       |
# | conf_obj   | 0.215769     | 0.262047     | 0.299699     |
# | conf_noobj | 0.008322     | 0.008195     | 0.007699     |
# +------------+--------------+--------------+--------------+
# Total loss 12.104764938354492
# ---- ETA 1:20:52.423920
#  67% 9771/14659 [1:20:42<50:06,  1.63it/s]
# ---- [Epoch 1/3, Batch 9772/14659] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 15           | 30           | 60           |
# | loss       | 3.243251     | 3.030737     | 2.698686     |
# | loss_x     | 0.083272     | 0.057367     | 0.068032     |
# | loss_y     | 0.048375     | 0.049963     | 0.063480     |
# | loss_w     | 0.281069     | 0.151294     | 0.129423     |
# | loss_h     | 0.183749     | 0.105514     | 0.144266     |
# | loss_obj   | 2.586031     | 2.607013     | 2.240215     |
# | loss_cls   | 0.060755     | 0.059587     | 0.053270     |
# | cls_acc    | 21.21%       | 19.44%       | 33.33%       |
# | conf_obj   | 0.339006     | 0.340910     | 0.394496     |
# | conf_noobj | 0.008767     | 0.008083     | 0.007424     |
# +------------+--------------+--------------+--------------+
# Total loss 8.972674369812012
# ---- ETA 0:40:22.225992
# 100% 14657/14659 [2:00:27<00:00,  2.15it/s]
# ---- [Epoch 1/3, Batch 14658/14659] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 12           | 24           | 48           |
# | loss       | 4.147463     | 3.818066     | 3.731955     |
# | loss_x     | 0.091546     | 0.076506     | 0.069608     |
# | loss_y     | 0.098319     | 0.053981     | 0.081333     |
# | loss_w     | 0.270451     | 0.233550     | 0.157244     |
# | loss_h     | 0.445362     | 0.222265     | 0.277807     |
# | loss_obj   | 3.183690     | 3.175793     | 3.089707     |
# | loss_cls   | 0.058095     | 0.055970     | 0.056256     |
# | cls_acc    | 18.92%       | 18.42%       | 28.95%       |
# | conf_obj   | 0.216957     | 0.203381     | 0.227373     |
# | conf_noobj | 0.008324     | 0.007655     | 0.007425     |
# +------------+--------------+--------------+--------------+
# Total loss 11.69748306274414
# ---- ETA 0:00:00.493103
# 100% 14659/14659 [2:00:28<00:00,  2.03it/s]
# Current epoch loss : 11.73901 Saved at checkpoints/Yolo_V3_coco.pth
# 14659
#  33% 4885/14659 [41:09<54:25,  2.99it/s]
# ---- [Epoch 2/3, Batch 4886/14659] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 10           | 20           | 40           |
# | loss       | 4.025529     | 3.942781     | 3.563370     |
# | loss_x     | 0.059975     | 0.079613     | 0.084536     |
# | loss_y     | 0.077048     | 0.066687     | 0.076474     |
# | loss_w     | 0.344927     | 0.102950     | 0.185468     |
# | loss_h     | 0.414111     | 0.109140     | 0.277256     |
# | loss_obj   | 3.063083     | 3.519419     | 2.874847     |
# | loss_cls   | 0.066385     | 0.064973     | 0.064790     |
# | cls_acc    | 14.81%       | 14.81%       | 14.81%       |
# | conf_obj   | 0.179889     | 0.132082     | 0.200683     |
# | conf_noobj | 0.008852     | 0.008158     | 0.007486     |
# +------------+--------------+--------------+--------------+
# Total loss 11.531681060791016
# ---- ETA 5:23:19.853195
#  67% 9771/14659 [1:22:05<39:12,  2.08it/s]
# ---- [Epoch 2/3, Batch 9772/14659] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 15           | 30           | 60           |
# | loss       | 4.782324     | 3.997733     | 3.691158     |
# | loss_x     | 0.051883     | 0.055953     | 0.059877     |
# | loss_y     | 0.078805     | 0.055409     | 0.079419     |
# | loss_w     | 0.288483     | 0.228419     | 0.281358     |
# | loss_h     | 0.336470     | 0.225053     | 0.238840     |
# | loss_obj   | 3.979348     | 3.385433     | 2.985347     |
# | loss_cls   | 0.047336     | 0.047466     | 0.046316     |
# | cls_acc    | 36.96%       | 38.30%       | 37.50%       |
# | conf_obj   | 0.132485     | 0.172734     | 0.215798     |
# | conf_noobj | 0.009018     | 0.007866     | 0.007120     |
# +------------+--------------+--------------+--------------+
# Total loss 12.47121524810791
# ---- ETA 1:41:19.057181
# 100% 14657/14659 [2:01:47<00:01,  1.75it/s]
# ---- [Epoch 2/3, Batch 14658/14659] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 16           | 32           | 64           |
# | loss       | 4.381258     | 3.980902     | 3.657293     |
# | loss_x     | 0.095352     | 0.069010     | 0.060008     |
# | loss_y     | 0.063489     | 0.047412     | 0.072017     |
# | loss_w     | 0.342097     | 0.191128     | 0.162285     |
# | loss_h     | 0.176807     | 0.147093     | 0.155724     |
# | loss_obj   | 3.642150     | 3.465456     | 3.153654     |
# | loss_cls   | 0.061363     | 0.060802     | 0.053606     |
# | cls_acc    | 25.37%       | 24.32%       | 34.21%       |
# | conf_obj   | 0.172632     | 0.213078     | 0.222294     |
# | conf_noobj | 0.008171     | 0.007447     | 0.007278     |
# +------------+--------------+--------------+--------------+
# Total loss 12.019453048706055
# ---- ETA 0:00:00.991776
# 100% 14659/14659 [2:01:48<00:00,  2.01it/s]
# Current epoch loss : 11.70332 Saved at checkpoints/Yolo_V3_coco.pth
# 14659
#  33% 4885/14659 [40:35<1:10:16,  2.32it/s]
# ---- [Epoch 3/3, Batch 4886/14659] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 12           | 24           | 48           |
# | loss       | 5.469433     | 4.296314     | 4.355709     |
# | loss_x     | 0.080061     | 0.072410     | 0.075305     |
# | loss_y     | 0.097457     | 0.088694     | 0.052863     |
# | loss_w     | 0.780303     | 0.192762     | 0.236086     |
# | loss_h     | 0.258368     | 0.166815     | 0.273854     |
# | loss_obj   | 4.200187     | 3.725836     | 3.669412     |
# | loss_cls   | 0.053057     | 0.049796     | 0.048190     |
# | cls_acc    | 37.04%       | 40.00%       | 40.62%       |
# | conf_obj   | 0.112458     | 0.167630     | 0.142849     |
# | conf_noobj | 0.009860     | 0.008450     | 0.007496     |
# +------------+--------------+--------------+--------------+
# Total loss 14.121456146240234
# ---- ETA 9:25:51.032575
#  67% 9771/14659 [1:20:17<45:25,  1.79it/s]
# ---- [Epoch 3/3, Batch 9772/14659] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 14           | 28           | 56           |
# | loss       | 4.250643     | 3.816624     | 3.510825     |
# | loss_x     | 0.070414     | 0.069241     | 0.084739     |
# | loss_y     | 0.087691     | 0.066659     | 0.034844     |
# | loss_w     | 0.264506     | 0.097219     | 0.103923     |
# | loss_h     | 0.247407     | 0.144233     | 0.082883     |
# | loss_obj   | 3.515539     | 3.376977     | 3.136395     |
# | loss_cls   | 0.065085     | 0.062295     | 0.068041     |
# | cls_acc    | 16.00%       | 16.00%       | 16.00%       |
# | conf_obj   | 0.174068     | 0.151518     | 0.181372     |
# | conf_noobj | 0.009186     | 0.008425     | 0.007437     |
# +------------+--------------+--------------+--------------+
# Total loss 11.578091621398926
# ---- ETA 2:41:20.267827
# 100% 14657/14659 [2:00:42<00:00,  2.85it/s]
# ---- [Epoch 3/3, Batch 14658/14659] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 10           | 20           | 40           |
# | loss       | 4.433107     | 3.921836     | 3.584381     |
# | loss_x     | 0.081646     | 0.067222     | 0.066490     |
# | loss_y     | 0.077724     | 0.064509     | 0.054921     |
# | loss_w     | 0.670992     | 0.286939     | 0.136234     |
# | loss_h     | 0.438259     | 0.245762     | 0.140578     |
# | loss_obj   | 3.105737     | 3.207658     | 3.141577     |
# | loss_cls   | 0.058749     | 0.049745     | 0.044581     |
# | cls_acc    | 39.47%       | 37.21%       | 36.96%       |
# | conf_obj   | 0.201325     | 0.215296     | 0.230569     |
# | conf_noobj | 0.007863     | 0.008105     | 0.007633     |
# +------------+--------------+--------------+--------------+
# Total loss 11.939323425292969
# ---- ETA 0:00:01.485957
# 100% 14659/14659 [2:00:43<00:00,  2.02it/s]
# Current epoch loss : 11.71241 Saved at checkpoints/Yolo_V3_coco.pth
#
# ---- Evaluating Model ----
# Detecting objects: 100% 619/619 [02:04<00:00,  4.96it/s]
# Computing AP: 100% 80/80 [00:00<00:00, 304.17it/s]
# +-------+----------------+---------+
# | Index | Class name     | AP      |
# +-------+----------------+---------+
# | 0     | person         | 0.14342 |
# | 1     | bicycle        | 0.00000 |
# | 2     | car            | 0.07654 |
# | 3     | motorbike      | 0.00000 |
# | 4     | aeroplane      | 0.00000 |
# | 5     | bus            | 0.00000 |
# | 6     | train          | 0.00000 |
# | 7     | truck          | 0.00000 |
# | 8     | boat           | 0.00000 |
# | 9     | traffic light  | 0.00000 |
# | 10    | fire hydrant   | 0.00000 |
# | 11    | stop sign      | 0.00000 |
# | 12    | parking meter  | 0.00000 |
# | 13    | bench          | 0.00000 |
# | 14    | bird           | 0.00000 |
# | 15    | cat            | 0.00000 |
# | 16    | dog            | 0.00000 |
# | 17    | horse          | 0.00000 |
# | 18    | sheep          | 0.00000 |
# | 19    | cow            | 0.00132 |
# | 20    | elephant       | 0.00000 |
# | 21    | bear           | 0.00000 |
# | 22    | zebra          | 0.00000 |
# | 23    | giraffe        | 0.00000 |
# | 24    | backpack       | 0.00000 |
# | 25    | umbrella       | 0.00000 |
# | 26    | handbag        | 0.00000 |
# | 27    | tie            | 0.00000 |
# | 28    | suitcase       | 0.00000 |
# | 29    | frisbee        | 0.00166 |
# | 30    | skis           | 0.00000 |
# | 31    | snowboard      | 0.00000 |
# | 32    | sports ball    | 0.01610 |
# | 33    | kite           | 0.00000 |
# | 34    | baseball bat   | 0.00000 |
# | 35    | baseball glove | 0.00000 |
# | 36    | skateboard     | 0.00000 |
# | 37    | surfboard      | 0.00000 |
# | 38    | tennis racket  | 0.00000 |
# | 39    | bottle         | 0.00423 |
# | 40    | wine glass     | 0.00000 |
# | 41    | cup            | 0.00638 |
# | 42    | fork           | 0.00000 |
# | 43    | knife          | 0.00000 |
# | 44    | spoon          | 0.00000 |
# | 45    | bowl           | 0.01633 |
# | 46    | banana         | 0.00000 |
# | 47    | apple          | 0.00000 |
# | 48    | sandwich       | 0.00000 |
# | 49    | orange         | 0.00000 |
# | 50    | broccoli       | 0.00000 |
# | 51    | carrot         | 0.00000 |
# | 52    | hot dog        | 0.00000 |
# | 53    | pizza          | 0.00113 |
# | 54    | donut          | 0.00299 |
# | 55    | cake           | 0.00000 |
# | 56    | chair          | 0.00000 |
# | 57    | sofa           | 0.00000 |
# | 58    | pottedplant    | 0.00000 |
# | 59    | bed            | 0.00000 |
# | 60    | diningtable    | 0.00000 |
# | 61    | toilet         | 0.00000 |
# | 62    | tvmonitor      | 0.00000 |
# | 63    | laptop         | 0.00000 |
# | 64    | mouse          | 0.00000 |
# | 65    | remote         | 0.00000 |
# | 66    | keyboard       | 0.00000 |
# | 67    | cell phone     | 0.00000 |
# | 68    | microwave      | 0.00000 |
# | 69    | oven           | 0.00000 |
# | 70    | toaster        | 0.00000 |
# | 71    | sink           | 0.00000 |
# | 72    | refrigerator   | 0.00000 |
# | 73    | book           | 0.00060 |
# | 74    | clock          | 0.00535 |
# | 75    | vase           | 0.00000 |
# | 76    | scissors       | 0.00000 |
# | 77    | teddy bear     | 0.00000 |
# | 78    | hair drier     | 0.00000 |
# | 79    | toothbrush     | 0.00000 |
# +-------+----------------+---------+
# ---- mAP 0.0034506579350019268

# %% [markdown]
# # 11. Train YOLO v3 from Darknet Weights

# %%
! python train.py --num_epochs 3 --batch_size 8 --data_config config/coco.data --model_def config/yolov3.cfg --pretrained_path checkpoints/yolov3.weights --save_path checkpoints/Yolo_V3_coco.pth
# Out:
# {'data_config': 'config/coco.data', 'model_def': 'config/yolov3.cfg', 'pretrained_path': 'checkpoints/yolov3.weights', 'save_path': 'checkpoints/Yolo_V3_coco.pth', 'working_dir': './', 'num_epochs': 3, 'batch_size': 8, 'img_size': 416, 'n_cpu': 1, 'gradient_accumulations': 2, 'evaluation_interval': 2, 'multiscale_training': True, 'checkpoint_freq': 2, 'iou_thres': 0.5, 'conf_thres': 0.5, 'nms_thres': 0.5, 'ckpt_dir': './checkpoints', 'logs_dir': './logs'}
# cuda
# checkpoints/yolov3.weights
# Darknet weight loaded!
# 14659
#  33% 4885/14659 [41:04<1:09:57,  2.33it/s]
# ---- [Epoch 1/3, Batch 4886/14659] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 12           | 24           | 48           |
# | loss       | 3.643074     | 3.316497     | 3.095438     |
# | loss_x     | 0.079718     | 0.061150     | 0.079792     |
# | loss_y     | 0.075128     | 0.063739     | 0.075961     |
# | loss_w     | 0.249819     | 0.089209     | 0.100302     |
# | loss_h     | 0.310324     | 0.118384     | 0.165623     |
# | loss_obj   | 2.875847     | 2.941196     | 2.629790     |
# | loss_cls   | 0.052238     | 0.042818     | 0.043970     |
# | cls_acc    | 41.67%       | 41.82%       | 40.00%       |
# | conf_obj   | 0.270075     | 0.260551     | 0.306699     |
# | conf_noobj | 0.008231     | 0.008233     | 0.008081     |
# +------------+--------------+--------------+--------------+
# Total loss 10.055008888244629
# ---- ETA 1:22:10.929744
#  67% 9771/14659 [1:21:15<53:53,  1.51it/s]
# ---- [Epoch 1/3, Batch 9772/14659] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 13           | 26           | 52           |
# | loss       | 5.044499     | 3.816252     | 3.143121     |
# | loss_x     | 0.077123     | 0.072565     | 0.076005     |
# | loss_y     | 0.059813     | 0.057565     | 0.065934     |
# | loss_w     | 0.762131     | 0.408991     | 0.232900     |
# | loss_h     | 0.771052     | 0.353190     | 0.202403     |
# | loss_obj   | 3.311575     | 2.869842     | 2.511259     |
# | loss_cls   | 0.062804     | 0.054099     | 0.054620     |
# | cls_acc    | 34.09%       | 38.30%       | 27.45%       |
# | conf_obj   | 0.183641     | 0.237307     | 0.319458     |
# | conf_noobj | 0.008264     | 0.006542     | 0.006613     |
# +------------+--------------+--------------+--------------+
# Total loss 12.00387191772461
# ---- ETA 0:40:38.729356
# 100% 14657/14659 [2:02:10<00:00,  2.28it/s]
# ---- [Epoch 1/3, Batch 14658/14659] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 12           | 24           | 48           |
# | loss       | 5.102367     | 4.210119     | 4.062078     |
# | loss_x     | 0.078692     | 0.062259     | 0.062711     |
# | loss_y     | 0.059342     | 0.062493     | 0.058815     |
# | loss_w     | 0.477530     | 0.200124     | 0.251863     |
# | loss_h     | 0.490012     | 0.244932     | 0.309292     |
# | loss_obj   | 3.940917     | 3.593461     | 3.332349     |
# | loss_cls   | 0.055874     | 0.046850     | 0.047047     |
# | cls_acc    | 46.34%       | 48.84%       | 45.45%       |
# | conf_obj   | 0.164772     | 0.201345     | 0.253255     |
# | conf_noobj | 0.008595     | 0.006730     | 0.006944     |
# +------------+--------------+--------------+--------------+
# Total loss 13.374565124511719
# ---- ETA 0:00:00.500132
# 100% 14659/14659 [2:02:11<00:00,  2.00it/s]
# Current epoch loss : 11.58012 Saved at checkpoints/Yolo_V3_coco.pth
# 14659
#  33% 4885/14659 [39:14<1:30:07,  1.81it/s]
# ---- [Epoch 2/3, Batch 4886/14659] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 16           | 32           | 64           |
# | loss       | 4.002662     | 3.440153     | 3.397183     |
# | loss_x     | 0.059771     | 0.058306     | 0.071334     |
# | loss_y     | 0.064926     | 0.064158     | 0.063136     |
# | loss_w     | 0.224501     | 0.145844     | 0.172754     |
# | loss_h     | 0.358906     | 0.121869     | 0.241574     |
# | loss_obj   | 3.248533     | 3.008003     | 2.807756     |
# | loss_cls   | 0.046025     | 0.041974     | 0.040629     |
# | cls_acc    | 46.88%       | 47.69%       | 52.94%       |
# | conf_obj   | 0.195366     | 0.215340     | 0.250266     |
# | conf_noobj | 0.008721     | 0.007853     | 0.007486     |
# +------------+--------------+--------------+--------------+
# Total loss 10.839999198913574
# ---- ETA 5:22:56.256287
#  67% 9771/14659 [1:19:35<45:35,  1.79it/s]
# ---- [Epoch 2/3, Batch 9772/14659] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 14           | 28           | 56           |
# | loss       | 4.576940     | 3.715649     | 3.491776     |
# | loss_x     | 0.101773     | 0.070699     | 0.054859     |
# | loss_y     | 0.085946     | 0.080263     | 0.067369     |
# | loss_w     | 0.416406     | 0.151126     | 0.158394     |
# | loss_h     | 0.266519     | 0.144456     | 0.197140     |
# | loss_obj   | 3.635592     | 3.213022     | 2.958985     |
# | loss_cls   | 0.070705     | 0.056081     | 0.055029     |
# | cls_acc    | 8.33%        | 21.15%       | 29.09%       |
# | conf_obj   | 0.146848     | 0.154924     | 0.196580     |
# | conf_noobj | 0.008583     | 0.007552     | 0.007286     |
# +------------+--------------+--------------+--------------+
# Total loss 11.784364700317383
# ---- ETA 1:40:55.144261
# 100% 14657/14659 [1:59:22<00:01,  1.66it/s]
# ---- [Epoch 2/3, Batch 14658/14659] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 16           | 32           | 64           |
# | loss       | 4.062257     | 3.219118     | 2.831742     |
# | loss_x     | 0.093865     | 0.066686     | 0.045361     |
# | loss_y     | 0.085976     | 0.043071     | 0.031815     |
# | loss_w     | 0.635115     | 0.274462     | 0.203577     |
# | loss_h     | 0.396084     | 0.278808     | 0.185337     |
# | loss_obj   | 2.788417     | 2.506503     | 2.326388     |
# | loss_cls   | 0.062800     | 0.049587     | 0.039265     |
# | cls_acc    | 29.79%       | 38.46%       | 40.00%       |
# | conf_obj   | 0.306282     | 0.328871     | 0.390905     |
# | conf_noobj | 0.008523     | 0.008512     | 0.007709     |
# +------------+--------------+--------------+--------------+
# Total loss 10.113116264343262
# ---- ETA 0:00:00.988860
# 100% 14659/14659 [1:59:23<00:00,  2.05it/s]
# Current epoch loss : 11.55418 Saved at checkpoints/Yolo_V3_coco.pth
# 14659
#  33% 4885/14659 [40:08<1:40:15,  1.62it/s]
# ---- [Epoch 3/3, Batch 4886/14659] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 15           | 30           | 60           |
# | loss       | 4.071769     | 3.661758     | 3.437150     |
# | loss_x     | 0.057178     | 0.077080     | 0.075290     |
# | loss_y     | 0.074267     | 0.072409     | 0.066031     |
# | loss_w     | 0.494218     | 0.284107     | 0.368360     |
# | loss_h     | 0.271599     | 0.177508     | 0.188920     |
# | loss_obj   | 3.123254     | 3.007386     | 2.695217     |
# | loss_cls   | 0.051253     | 0.043268     | 0.043332     |
# | cls_acc    | 44.90%       | 49.06%       | 50.88%       |
# | conf_obj   | 0.228179     | 0.251362     | 0.301624     |
# | conf_noobj | 0.008289     | 0.008039     | 0.007657     |
# +------------+--------------+--------------+--------------+
# Total loss 11.170677185058594
# ---- ETA 9:23:31.925627
#  67% 9771/14659 [1:20:12<47:09,  1.73it/s]
# ---- [Epoch 3/3, Batch 9772/14659] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 10           | 20           | 40           |
# | loss       | 5.124517     | 4.840940     | 4.909140     |
# | loss_x     | 0.105592     | 0.079915     | 0.061954     |
# | loss_y     | 0.069642     | 0.082713     | 0.064153     |
# | loss_w     | 0.376735     | 0.221655     | 0.318966     |
# | loss_h     | 0.567281     | 0.255995     | 0.339347     |
# | loss_obj   | 3.936584     | 4.140328     | 4.066815     |
# | loss_cls   | 0.068683     | 0.060334     | 0.057905     |
# | cls_acc    | 8.00%        | 9.26%        | 22.22%       |
# | conf_obj   | 0.119207     | 0.124241     | 0.121128     |
# | conf_noobj | 0.008105     | 0.008104     | 0.007789     |
# +------------+--------------+--------------+--------------+
# Total loss 14.874597549438477
# ---- ETA 2:40:56.087435
# 100% 14657/14659 [1:59:41<00:00,  2.69it/s]
# ---- [Epoch 3/3, Batch 14658/14659] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 10           | 20           | 40           |
# | loss       | 3.817293     | 3.407124     | 3.213880     |
# | loss_x     | 0.050617     | 0.055603     | 0.090238     |
# | loss_y     | 0.051378     | 0.068408     | 0.074234     |
# | loss_w     | 0.335560     | 0.176278     | 0.141987     |
# | loss_h     | 0.278282     | 0.205451     | 0.084674     |
# | loss_obj   | 3.037458     | 2.850166     | 2.773062     |
# | loss_cls   | 0.063999     | 0.051218     | 0.049686     |
# | cls_acc    | 30.43%       | 34.78%       | 43.48%       |
# | conf_obj   | 0.155616     | 0.219241     | 0.214231     |
# | conf_noobj | 0.007751     | 0.008205     | 0.007630     |
# +------------+--------------+--------------+--------------+
# Total loss 10.438297271728516
# ---- ETA 0:00:01.478910
# 100% 14659/14659 [1:59:42<00:00,  2.04it/s]
# Current epoch loss : 11.54436 Saved at checkpoints/Yolo_V3_coco.pth
#
# ---- Evaluating Model ----
# Detecting objects: 100% 619/619 [02:00<00:00,  5.12it/s]
# Computing AP: 100% 80/80 [00:00<00:00, 330.89it/s]
# +-------+----------------+---------+
# | Index | Class name     | AP      |
# +-------+----------------+---------+
# | 0     | person         | 0.20822 |
# | 1     | bicycle        | 0.00000 |
# | 2     | car            | 0.16708 |
# | 3     | motorbike      | 0.00000 |
# | 4     | aeroplane      | 0.00350 |
# | 5     | bus            | 0.00000 |
# | 6     | train          | 0.00000 |
# | 7     | truck          | 0.00138 |
# | 8     | boat           | 0.00310 |
# | 9     | traffic light  | 0.00078 |
# | 10    | fire hydrant   | 0.00000 |
# | 11    | stop sign      | 0.00000 |
# | 12    | parking meter  | 0.00000 |
# | 13    | bench          | 0.00000 |
# | 14    | bird           | 0.00233 |
# | 15    | cat            | 0.00000 |
# | 16    | dog            | 0.00000 |
# | 17    | horse          | 0.00000 |
# | 18    | sheep          | 0.00687 |
# | 19    | cow            | 0.01219 |
# | 20    | elephant       | 0.00000 |
# | 21    | bear           | 0.00000 |
# | 22    | zebra          | 0.00000 |
# | 23    | giraffe        | 0.00000 |
# | 24    | backpack       | 0.00000 |
# | 25    | umbrella       | 0.00242 |
# | 26    | handbag        | 0.00000 |
# | 27    | tie            | 0.01230 |
# | 28    | suitcase       | 0.00000 |
# | 29    | frisbee        | 0.00514 |
# | 30    | skis           | 0.00986 |
# | 31    | snowboard      | 0.00000 |
# | 32    | sports ball    | 0.16691 |
# | 33    | kite           | 0.00000 |
# | 34    | baseball bat   | 0.00685 |
# | 35    | baseball glove | 0.00000 |
# | 36    | skateboard     | 0.00571 |
# | 37    | surfboard      | 0.00074 |
# | 38    | tennis racket  | 0.00000 |
# | 39    | bottle         | 0.04488 |
# | 40    | wine glass     | 0.00146 |
# | 41    | cup            | 0.06326 |
# | 42    | fork           | 0.00000 |
# | 43    | knife          | 0.00000 |
# | 44    | spoon          | 0.00000 |
# | 45    | bowl           | 0.02228 |
# | 46    | banana         | 0.00000 |
# | 47    | apple          | 0.00113 |
# | 48    | sandwich       | 0.00000 |
# | 49    | orange         | 0.00000 |
# | 50    | broccoli       | 0.00000 |
# | 51    | carrot         | 0.00000 |
# | 52    | hot dog        | 0.00000 |
# | 53    | pizza          | 0.00005 |
# | 54    | donut          | 0.00440 |
# | 55    | cake           | 0.00000 |
# | 56    | chair          | 0.00361 |
# | 57    | sofa           | 0.00000 |
# | 58    | pottedplant    | 0.00000 |
# | 59    | bed            | 0.00000 |
# | 60    | diningtable    | 0.00000 |
# | 61    | toilet         | 0.00000 |
# | 62    | tvmonitor      | 0.00058 |
# | 63    | laptop         | 0.00000 |
# | 64    | mouse          | 0.00314 |
# | 65    | remote         | 0.00000 |
# | 66    | keyboard       | 0.00000 |
# | 67    | cell phone     | 0.00000 |
# | 68    | microwave      | 0.00000 |
# | 69    | oven           | 0.00000 |
# | 70    | toaster        | 0.00000 |
# | 71    | sink           | 0.02239 |
# | 72    | refrigerator   | 0.00000 |
# | 73    | book           | 0.00793 |
# | 74    | clock          | 0.13266 |
# | 75    | vase           | 0.00144 |
# | 76    | scissors       | 0.00000 |
# | 77    | teddy bear     | 0.00000 |
# | 78    | hair drier     | 0.00000 |
# | 79    | toothbrush     | 0.00000 |
# +-------+----------------+---------+
# ---- mAP 0.011557327593293153

# %% [markdown]
# # 12. Train YOLO v3-tiny from Pre-trained Weights

# %%
! python train.py --num_epochs 3 --batch_size 32 --data_config config/coco.data --model_def config/yolov3-tiny.cfg --pretrained_path checkpoints/Yolo_V3_coco_tiny.pth --save_path checkpoints/Yolo_V3_coco_tiny.pth
# Out:
# {'data_config': 'config/coco.data', 'model_def': 'config/yolov3-tiny.cfg', 'pretrained_path': 'checkpoints/Yolo_V3_coco_tiny.pth', 'save_path': 'checkpoints/Yolo_V3_coco_tiny.pth', 'working_dir': './', 'num_epochs': 3, 'batch_size': 32, 'img_size': 416, 'n_cpu': 1, 'gradient_accumulations': 2, 'evaluation_interval': 2, 'multiscale_training': True, 'checkpoint_freq': 2, 'iou_thres': 0.5, 'conf_thres': 0.5, 'nms_thres': 0.5, 'ckpt_dir': './checkpoints', 'logs_dir': './logs'}
# cuda
# checkpoints/Yolo_V3_coco_tiny.pth
# Trained pytorch weight loaded!
# 3665
#  33% 1220/3665 [10:14<21:07,  1.93it/s]
# ---- [Epoch 1/3, Batch 1221/3665] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 10           | 20           |
# | loss       | 3.652514     | 3.267475     |
# | loss_x     | 0.068368     | 0.057375     |
# | loss_y     | 0.062639     | 0.068114     |
# | loss_w     | 0.419175     | 0.233337     |
# | loss_h     | 0.280333     | 0.136208     |
# | loss_obj   | 2.779319     | 2.737706     |
# | loss_cls   | 0.042680     | 0.034735     |
# | cls_acc    | 46.41%       | 56.04%       |
# | conf_obj   | 0.266656     | 0.289736     |
# | conf_noobj | 0.007371     | 0.007670     |
# +------------+--------------+--------------+
# Total loss 6.919989585876465
# ---- ETA 0:20:30.445861
#  67% 2441/3665 [20:19<10:11,  2.00it/s]
# ---- [Epoch 1/3, Batch 2442/3665] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 15           | 30           |
# | loss       | 3.024393     | 3.102065     |
# | loss_x     | 0.055307     | 0.068234     |
# | loss_y     | 0.063886     | 0.069295     |
# | loss_w     | 0.212936     | 0.192266     |
# | loss_h     | 0.179100     | 0.117555     |
# | loss_obj   | 2.485792     | 2.632183     |
# | loss_cls   | 0.027371     | 0.022531     |
# | cls_acc    | 65.33%       | 67.30%       |
# | conf_obj   | 0.326160     | 0.311688     |
# | conf_noobj | 0.007361     | 0.007454     |
# +------------+--------------+--------------+
# Total loss 6.126458168029785
# ---- ETA 0:10:11.084114
# 100% 3662/3665 [30:27<00:01,  2.06it/s]
# ---- [Epoch 1/3, Batch 3663/3665] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 13           | 26           |
# | loss       | 3.595928     | 3.154624     |
# | loss_x     | 0.064210     | 0.070328     |
# | loss_y     | 0.049317     | 0.068839     |
# | loss_w     | 0.349561     | 0.182204     |
# | loss_h     | 0.298618     | 0.171712     |
# | loss_obj   | 2.799440     | 2.634447     |
# | loss_cls   | 0.034781     | 0.027094     |
# | cls_acc    | 55.10%       | 58.08%       |
# | conf_obj   | 0.260998     | 0.313659     |
# | conf_noobj | 0.006943     | 0.006854     |
# +------------+--------------+--------------+
# Total loss 6.750552177429199
# ---- ETA 0:00:00.998328
# 100% 3665/3665 [30:29<00:00,  2.00it/s]
# Current epoch loss : 7.08954 Saved at checkpoints/Yolo_V3_coco_tiny.pth
# 3665
#  33% 1220/3665 [09:21<18:31,  2.20it/s]
# ---- [Epoch 2/3, Batch 1221/3665] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 11           | 22           |
# | loss       | 3.627183     | 3.364866     |
# | loss_x     | 0.071583     | 0.059654     |
# | loss_y     | 0.064469     | 0.061792     |
# | loss_w     | 0.423165     | 0.326015     |
# | loss_h     | 0.381183     | 0.238115     |
# | loss_obj   | 2.656517     | 2.654357     |
# | loss_cls   | 0.030267     | 0.024932     |
# | cls_acc    | 65.13%       | 69.70%       |
# | conf_obj   | 0.310216     | 0.324347     |
# | conf_noobj | 0.006524     | 0.007322     |
# +------------+--------------+--------------+
# Total loss 6.992048740386963
# ---- ETA 1:19:45.911505
#  67% 2441/3665 [19:05<10:17,  1.98it/s]
# ---- [Epoch 2/3, Batch 2442/3665] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 16           | 32           |
# | loss       | 3.236415     | 3.148736     |
# | loss_x     | 0.067815     | 0.063589     |
# | loss_y     | 0.062643     | 0.057465     |
# | loss_w     | 0.207448     | 0.161982     |
# | loss_h     | 0.147343     | 0.144378     |
# | loss_obj   | 2.717111     | 2.690174     |
# | loss_cls   | 0.034055     | 0.031148     |
# | cls_acc    | 56.10%       | 57.71%       |
# | conf_obj   | 0.270658     | 0.275340     |
# | conf_noobj | 0.006841     | 0.006574     |
# +------------+--------------+--------------+
# Total loss 6.385150909423828
# ---- ETA 0:24:50.158746
# 100% 3662/3665 [28:49<00:01,  1.99it/s]
# ---- [Epoch 2/3, Batch 3663/3665] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 16           | 32           |
# | loss       | 3.535728     | 3.322095     |
# | loss_x     | 0.077495     | 0.073750     |
# | loss_y     | 0.063794     | 0.057775     |
# | loss_w     | 0.300207     | 0.233598     |
# | loss_h     | 0.204004     | 0.152608     |
# | loss_obj   | 2.861425     | 2.780108     |
# | loss_cls   | 0.028802     | 0.024256     |
# | cls_acc    | 66.96%       | 72.33%       |
# | conf_obj   | 0.245541     | 0.264176     |
# | conf_noobj | 0.007042     | 0.007023     |
# +------------+--------------+--------------+
# Total loss 6.857823371887207
# ---- ETA 0:00:01.943605
# 100% 3665/3665 [28:51<00:00,  2.12it/s]
# Current epoch loss : 7.05012 Saved at checkpoints/Yolo_V3_coco_tiny.pth
# 3665
#  33% 1220/3665 [09:17<19:13,  2.12it/s]
# ---- [Epoch 3/3, Batch 1221/3665] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 16           | 32           |
# | loss       | 3.295441     | 3.134605     |
# | loss_x     | 0.069062     | 0.071090     |
# | loss_y     | 0.065521     | 0.060837     |
# | loss_w     | 0.251184     | 0.147666     |
# | loss_h     | 0.267117     | 0.168094     |
# | loss_obj   | 2.605501     | 2.654929     |
# | loss_cls   | 0.037054     | 0.031989     |
# | cls_acc    | 43.15%       | 50.19%       |
# | conf_obj   | 0.279239     | 0.289739     |
# | conf_noobj | 0.007475     | 0.007064     |
# +------------+--------------+--------------+
# Total loss 6.430046081542969
# ---- ETA 2:17:23.434931
#  67% 2441/3665 [18:53<10:23,  1.96it/s]
# ---- [Epoch 3/3, Batch 2442/3665] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 15           | 30           |
# | loss       | 3.605166     | 3.327194     |
# | loss_x     | 0.064399     | 0.066497     |
# | loss_y     | 0.056915     | 0.066956     |
# | loss_w     | 0.303673     | 0.242961     |
# | loss_h     | 0.309792     | 0.183605     |
# | loss_obj   | 2.837804     | 2.743033     |
# | loss_cls   | 0.032584     | 0.024142     |
# | cls_acc    | 57.04%       | 65.84%       |
# | conf_obj   | 0.250968     | 0.304992     |
# | conf_noobj | 0.008141     | 0.007988     |
# +------------+--------------+--------------+
# Total loss 6.932360649108887
# ---- ETA 0:39:10.914241
# 100% 3662/3665 [28:28<00:01,  2.01it/s]
# ---- [Epoch 3/3, Batch 3663/3665] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 16           | 32           |
# | loss       | 3.303558     | 3.014610     |
# | loss_x     | 0.070152     | 0.071881     |
# | loss_y     | 0.063294     | 0.059984     |
# | loss_w     | 0.270131     | 0.183483     |
# | loss_h     | 0.207786     | 0.129874     |
# | loss_obj   | 2.663296     | 2.545230     |
# | loss_cls   | 0.028901     | 0.024157     |
# | cls_acc    | 60.00%       | 68.13%       |
# | conf_obj   | 0.322181     | 0.333591     |
# | conf_noobj | 0.006880     | 0.006529     |
# +------------+--------------+--------------+
# Total loss 6.318167686462402
# ---- ETA 0:00:02.877076
# 100% 3665/3665 [28:29<00:00,  2.14it/s]
# Current epoch loss : 7.04479 Saved at checkpoints/Yolo_V3_coco_tiny.pth
#
# ---- Evaluating Model ----
# Detecting objects: 100% 155/155 [01:10<00:00,  2.21it/s]
# Computing AP: 100% 80/80 [00:00<00:00, 363.34it/s]
# +-------+----------------+---------+
# | Index | Class name     | AP      |
# +-------+----------------+---------+
# | 0     | person         | 0.19004 |
# | 1     | bicycle        | 0.04458 |
# | 2     | car            | 0.09278 |
# | 3     | motorbike      | 0.07268 |
# | 4     | aeroplane      | 0.02875 |
# | 5     | bus            | 0.13370 |
# | 6     | train          | 0.10408 |
# | 7     | truck          | 0.01460 |
# | 8     | boat           | 0.00695 |
# | 9     | traffic light  | 0.06645 |
# | 10    | fire hydrant   | 0.08911 |
# | 11    | stop sign      | 0.24863 |
# | 12    | parking meter  | 0.01667 |
# | 13    | bench          | 0.01211 |
# | 14    | bird           | 0.00293 |
# | 15    | cat            | 0.07295 |
# | 16    | dog            | 0.03459 |
# | 17    | horse          | 0.08458 |
# | 18    | sheep          | 0.12971 |
# | 19    | cow            | 0.03998 |
# | 20    | elephant       | 0.15380 |
# | 21    | bear           | 0.01408 |
# | 22    | zebra          | 0.24686 |
# | 23    | giraffe        | 0.25010 |
# | 24    | backpack       | 0.00118 |
# | 25    | umbrella       | 0.05301 |
# | 26    | handbag        | 0.00541 |
# | 27    | tie            | 0.06696 |
# | 28    | suitcase       | 0.00880 |
# | 29    | frisbee        | 0.13353 |
# | 30    | skis           | 0.04427 |
# | 31    | snowboard      | 0.02070 |
# | 32    | sports ball    | 0.10827 |
# | 33    | kite           | 0.05832 |
# | 34    | baseball bat   | 0.03974 |
# | 35    | baseball glove | 0.03210 |
# | 36    | skateboard     | 0.07301 |
# | 37    | surfboard      | 0.04469 |
# | 38    | tennis racket  | 0.17787 |
# | 39    | bottle         | 0.05258 |
# | 40    | wine glass     | 0.03749 |
# | 41    | cup            | 0.09883 |
# | 42    | fork           | 0.01000 |
# | 43    | knife          | 0.01065 |
# | 44    | spoon          | 0.00896 |
# | 45    | bowl           | 0.08463 |
# | 46    | banana         | 0.00366 |
# | 47    | apple          | 0.00000 |
# | 48    | sandwich       | 0.02443 |
# | 49    | orange         | 0.06215 |
# | 50    | broccoli       | 0.01537 |
# | 51    | carrot         | 0.00754 |
# | 52    | hot dog        | 0.01575 |
# | 53    | pizza          | 0.09868 |
# | 54    | donut          | 0.06607 |
# | 55    | cake           | 0.04263 |
# | 56    | chair          | 0.03150 |
# | 57    | sofa           | 0.09629 |
# | 58    | pottedplant    | 0.03467 |
# | 59    | bed            | 0.01227 |
# | 60    | diningtable    | 0.00133 |
# | 61    | toilet         | 0.23576 |
# | 62    | tvmonitor      | 0.22719 |
# | 63    | laptop         | 0.13757 |
# | 64    | mouse          | 0.14141 |
# | 65    | remote         | 0.02360 |
# | 66    | keyboard       | 0.17464 |
# | 67    | cell phone     | 0.06751 |
# | 68    | microwave      | 0.16246 |
# | 69    | oven           | 0.04614 |
# | 70    | toaster        | 0.00000 |
# | 71    | sink           | 0.10640 |
# | 72    | refrigerator   | 0.06361 |
# | 73    | book           | 0.00869 |
# | 74    | clock          | 0.33462 |
# | 75    | vase           | 0.03318 |
# | 76    | scissors       | 0.02778 |
# | 77    | teddy bear     | 0.01571 |
# | 78    | hair drier     | 0.00000 |
# | 79    | toothbrush     | 0.00000 |
# +-------+----------------+---------+
# ---- mAP 0.0705035245684871

# %% [markdown]
# # 13. Train YOLO v3-tiny from Darknet Weights

# %%
! python train.py --num_epochs 3 --batch_size 32 --data_config config/coco.data --model_def config/yolov3-tiny.cfg --pretrained_path checkpoints/yolov3-tiny.weights --save_path checkpoints/Yolo_V3_coco_tiny.pth
# Out:
# {'data_config': 'config/coco.data', 'model_def': 'config/yolov3-tiny.cfg', 'pretrained_path': 'checkpoints/yolov3-tiny.weights', 'save_path': 'checkpoints/Yolo_V3_coco_tiny.pth', 'working_dir': './', 'num_epochs': 3, 'batch_size': 32, 'img_size': 416, 'n_cpu': 1, 'gradient_accumulations': 2, 'evaluation_interval': 2, 'multiscale_training': True, 'checkpoint_freq': 2, 'iou_thres': 0.5, 'conf_thres': 0.5, 'nms_thres': 0.5, 'ckpt_dir': './checkpoints', 'logs_dir': './logs'}
# cuda
# checkpoints/yolov3-tiny.weights
# Darknet weight loaded!
# 3665
#  33% 1220/3665 [10:31<20:40,  1.97it/s]
# ---- [Epoch 1/3, Batch 1221/3665] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 16           | 32           |
# | loss       | 3.236423     | 2.828643     |
# | loss_x     | 0.068710     | 0.056973     |
# | loss_y     | 0.052256     | 0.054188     |
# | loss_w     | 0.218606     | 0.162353     |
# | loss_h     | 0.229760     | 0.137007     |
# | loss_obj   | 2.642068     | 2.397979     |
# | loss_cls   | 0.025023     | 0.020142     |
# | cls_acc    | 70.51%       | 76.03%       |
# | conf_obj   | 0.303058     | 0.364265     |
# | conf_noobj | 0.006632     | 0.006304     |
# +------------+--------------+--------------+
# Total loss 6.065065860748291
# ---- ETA 0:21:05.658657
#  67% 2441/3665 [20:57<10:34,  1.93it/s]
# ---- [Epoch 1/3, Batch 2442/3665] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 11           | 22           |
# | loss       | 3.683639     | 3.583519     |
# | loss_x     | 0.052602     | 0.062327     |
# | loss_y     | 0.059013     | 0.061387     |
# | loss_w     | 0.404700     | 0.210500     |
# | loss_h     | 0.363800     | 0.187711     |
# | loss_obj   | 2.772526     | 3.034495     |
# | loss_cls   | 0.030997     | 0.027099     |
# | cls_acc    | 59.62%       | 61.89%       |
# | conf_obj   | 0.296849     | 0.287517     |
# | conf_noobj | 0.006113     | 0.007276     |
# +------------+--------------+--------------+
# Total loss 7.267157554626465
# ---- ETA 0:10:30.023985
# 100% 3662/3665 [31:15<00:01,  2.04it/s]
# ---- [Epoch 1/3, Batch 3663/3665] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 10           | 20           |
# | loss       | 4.076243     | 3.544818     |
# | loss_x     | 0.077436     | 0.065523     |
# | loss_y     | 0.070145     | 0.058060     |
# | loss_w     | 0.479710     | 0.302477     |
# | loss_h     | 0.405918     | 0.170194     |
# | loss_obj   | 3.008583     | 2.922295     |
# | loss_cls   | 0.034451     | 0.026270     |
# | cls_acc    | 52.38%       | 64.65%       |
# | conf_obj   | 0.235715     | 0.257003     |
# | conf_noobj | 0.008002     | 0.007581     |
# +------------+--------------+--------------+
# Total loss 7.621061325073242
# ---- ETA 0:00:01.024251
# 100% 3665/3665 [31:16<00:00,  1.95it/s]
# Current epoch loss : 6.99675 Saved at checkpoints/Yolo_V3_coco_tiny.pth
# 3665
#  33% 1220/3665 [09:38<20:10,  2.02it/s]
# ---- [Epoch 2/3, Batch 1221/3665] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 14           | 28           |
# | loss       | 3.489262     | 3.219857     |
# | loss_x     | 0.071741     | 0.074896     |
# | loss_y     | 0.057709     | 0.061564     |
# | loss_w     | 0.291681     | 0.197341     |
# | loss_h     | 0.317289     | 0.178344     |
# | loss_obj   | 2.724085     | 2.685882     |
# | loss_cls   | 0.026758     | 0.021830     |
# | cls_acc    | 65.41%       | 69.61%       |
# | conf_obj   | 0.289666     | 0.294001     |
# | conf_noobj | 0.007287     | 0.007133     |
# +------------+--------------+--------------+
# Total loss 6.70911979675293
# ---- ETA 1:21:55.819753
#  67% 2441/3665 [19:41<09:43,  2.10it/s]
# ---- [Epoch 2/3, Batch 2442/3665] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 11           | 22           |
# | loss       | 3.675193     | 3.490894     |
# | loss_x     | 0.071696     | 0.058882     |
# | loss_y     | 0.054937     | 0.062568     |
# | loss_w     | 0.514919     | 0.243908     |
# | loss_h     | 0.287116     | 0.137301     |
# | loss_obj   | 2.716872     | 2.964081     |
# | loss_cls   | 0.029654     | 0.024153     |
# | cls_acc    | 56.90%       | 66.33%       |
# | conf_obj   | 0.299662     | 0.284496     |
# | conf_noobj | 0.007319     | 0.007647     |
# +------------+--------------+--------------+
# Total loss 7.1660871505737305
# ---- ETA 0:25:31.906537
# 100% 3662/3665 [29:27<00:01,  2.09it/s]
# ---- [Epoch 2/3, Batch 3663/3665] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 12           | 24           |
# | loss       | 3.817651     | 3.347470     |
# | loss_x     | 0.059306     | 0.054621     |
# | loss_y     | 0.057375     | 0.064244     |
# | loss_w     | 0.434523     | 0.164684     |
# | loss_h     | 0.383460     | 0.139589     |
# | loss_obj   | 2.849975     | 2.899006     |
# | loss_cls   | 0.033012     | 0.025326     |
# | cls_acc    | 52.73%       | 65.59%       |
# | conf_obj   | 0.220129     | 0.240294     |
# | conf_noobj | 0.007534     | 0.007208     |
# +------------+--------------+--------------+
# Total loss 7.1651201248168945
# ---- ETA 0:00:01.990071
# 100% 3665/3665 [29:28<00:00,  2.07it/s]
# Current epoch loss : 6.93796 Saved at checkpoints/Yolo_V3_coco_tiny.pth
# 3665
#  33% 1220/3665 [09:23<20:07,  2.02it/s]
# ---- [Epoch 3/3, Batch 1221/3665] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 16           | 32           |
# | loss       | 3.219827     | 2.932124     |
# | loss_x     | 0.063440     | 0.078266     |
# | loss_y     | 0.051737     | 0.071559     |
# | loss_w     | 0.304419     | 0.198121     |
# | loss_h     | 0.186484     | 0.104473     |
# | loss_obj   | 2.587767     | 2.459062     |
# | loss_cls   | 0.025980     | 0.020643     |
# | cls_acc    | 65.84%       | 68.16%       |
# | conf_obj   | 0.303213     | 0.321731     |
# | conf_noobj | 0.007336     | 0.006775     |
# +------------+--------------+--------------+
# Total loss 6.151951789855957
# ---- ETA 2:20:27.163050
#  67% 2441/3665 [19:10<10:13,  2.00it/s]
# ---- [Epoch 3/3, Batch 2442/3665] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 16           | 32           |
# | loss       | 3.474366     | 3.182252     |
# | loss_x     | 0.078059     | 0.073407     |
# | loss_y     | 0.060693     | 0.064488     |
# | loss_w     | 0.304455     | 0.170558     |
# | loss_h     | 0.303668     | 0.193679     |
# | loss_obj   | 2.700448     | 2.656085     |
# | loss_cls   | 0.027044     | 0.024036     |
# | cls_acc    | 62.72%       | 65.20%       |
# | conf_obj   | 0.266296     | 0.271131     |
# | conf_noobj | 0.006795     | 0.006681     |
# +------------+--------------+--------------+
# Total loss 6.656618595123291
# ---- ETA 0:40:02.550734
# 100% 3662/3665 [28:59<00:01,  1.97it/s]
# ---- [Epoch 3/3, Batch 3663/3665] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 16           | 32           |
# | loss       | 3.359025     | 3.258628     |
# | loss_x     | 0.065086     | 0.066333     |
# | loss_y     | 0.062832     | 0.055559     |
# | loss_w     | 0.273675     | 0.163353     |
# | loss_h     | 0.231294     | 0.135239     |
# | loss_obj   | 2.699843     | 2.816935     |
# | loss_cls   | 0.026295     | 0.021209     |
# | cls_acc    | 63.92%       | 68.25%       |
# | conf_obj   | 0.274053     | 0.258558     |
# | conf_noobj | 0.007191     | 0.006588     |
# +------------+--------------+--------------+
# Total loss 6.617653846740723
# ---- ETA 0:00:02.940491
# 100% 3665/3665 [29:00<00:00,  2.11it/s]
# Current epoch loss : 6.92348 Saved at checkpoints/Yolo_V3_coco_tiny.pth
#
# ---- Evaluating Model ----
# Detecting objects: 100% 155/155 [01:12<00:00,  2.15it/s]
# Computing AP: 100% 80/80 [00:00<00:00, 368.15it/s]
# +-------+----------------+---------+
# | Index | Class name     | AP      |
# +-------+----------------+---------+
# | 0     | person         | 0.19511 |
# | 1     | bicycle        | 0.08179 |
# | 2     | car            | 0.08724 |
# | 3     | motorbike      | 0.04693 |
# | 4     | aeroplane      | 0.04573 |
# | 5     | bus            | 0.10694 |
# | 6     | train          | 0.10694 |
# | 7     | truck          | 0.01266 |
# | 8     | boat           | 0.00706 |
# | 9     | traffic light  | 0.08648 |
# | 10    | fire hydrant   | 0.23220 |
# | 11    | stop sign      | 0.35967 |
# | 12    | parking meter  | 0.06667 |
# | 13    | bench          | 0.01958 |
# | 14    | bird           | 0.01588 |
# | 15    | cat            | 0.12359 |
# | 16    | dog            | 0.08875 |
# | 17    | horse          | 0.13000 |
# | 18    | sheep          | 0.13543 |
# | 19    | cow            | 0.12725 |
# | 20    | elephant       | 0.20413 |
# | 21    | bear           | 0.17226 |
# | 22    | zebra          | 0.31796 |
# | 23    | giraffe        | 0.28275 |
# | 24    | backpack       | 0.01316 |
# | 25    | umbrella       | 0.07887 |
# | 26    | handbag        | 0.00520 |
# | 27    | tie            | 0.09203 |
# | 28    | suitcase       | 0.03201 |
# | 29    | frisbee        | 0.16956 |
# | 30    | skis           | 0.04053 |
# | 31    | snowboard      | 0.07607 |
# | 32    | sports ball    | 0.11751 |
# | 33    | kite           | 0.07295 |
# | 34    | baseball bat   | 0.04285 |
# | 35    | baseball glove | 0.10073 |
# | 36    | skateboard     | 0.10660 |
# | 37    | surfboard      | 0.04188 |
# | 38    | tennis racket  | 0.14134 |
# | 39    | bottle         | 0.06034 |
# | 40    | wine glass     | 0.05083 |
# | 41    | cup            | 0.09488 |
# | 42    | fork           | 0.01932 |
# | 43    | knife          | 0.01637 |
# | 44    | spoon          | 0.00593 |
# | 45    | bowl           | 0.11352 |
# | 46    | banana         | 0.02514 |
# | 47    | apple          | 0.02410 |
# | 48    | sandwich       | 0.05556 |
# | 49    | orange         | 0.12398 |
# | 50    | broccoli       | 0.05404 |
# | 51    | carrot         | 0.03007 |
# | 52    | hot dog        | 0.00990 |
# | 53    | pizza          | 0.14615 |
# | 54    | donut          | 0.13793 |
# | 55    | cake           | 0.07639 |
# | 56    | chair          | 0.03866 |
# | 57    | sofa           | 0.09095 |
# | 58    | pottedplant    | 0.01699 |
# | 59    | bed            | 0.01022 |
# | 60    | diningtable    | 0.00118 |
# | 61    | toilet         | 0.31616 |
# | 62    | tvmonitor      | 0.23267 |
# | 63    | laptop         | 0.20611 |
# | 64    | mouse          | 0.21172 |
# | 65    | remote         | 0.01938 |
# | 66    | keyboard       | 0.14461 |
# | 67    | cell phone     | 0.08887 |
# | 68    | microwave      | 0.15925 |
# | 69    | oven           | 0.05982 |
# | 70    | toaster        | 0.00000 |
# | 71    | sink           | 0.11494 |
# | 72    | refrigerator   | 0.08510 |
# | 73    | book           | 0.00981 |
# | 74    | clock          | 0.31477 |
# | 75    | vase           | 0.05220 |
# | 76    | scissors       | 0.00000 |
# | 77    | teddy bear     | 0.08536 |
# | 78    | hair drier     | 0.00000 |
# | 79    | toothbrush     | 0.00000 |
# +-------+----------------+---------+
# ---- mAP 0.09359413302104769
